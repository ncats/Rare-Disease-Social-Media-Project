# %% [markdown]
# Get GARD Dictionary

# %%
## Section: GARD SEARCH
# can identify rare diseases in text using the GARD dictionary from neo4j
# and map a GARD ID, name, or synonym to all of the related synonyms for searching APIs
from typing import List, Dict, Union, Optional, Set, Tuple
from nltk import tokenize as nltk_tokenize
import requests

class GARD_Search:
    def __init__(self):
        import json, codecs
        #These are opened locally so that garbage collection removes them from memory
        try:
            with codecs.open('gard-id-name-synonyms.json', 'r', 'utf-8-sig') as f:
                diseases = json.load(f)
        except:
            r = requests.get('https://raw.githubusercontent.com/ncats/epi4GARD/master/EpiExtract4GARD/gard-id-name-synonyms.json')
            diseases = json.loads(r.content)
        
        from nltk.corpus import stopwords
        try:
            STOPWORDS = set(stopwords.words('english'))
        except:
            import nltk
            nltk.download('stopwords')
            STOPWORDS = set(stopwords.words('english'))
        
        #This should be a list of all GARD IDs for purposes like random choice for testing
        GARD_id_list = [entry['gard_id'] for entry in diseases]
        #keys are going to be disease names, values are going to be the GARD ID, set up this way bc dictionaries are faster lookup than lists
        GARD_dict = {}
        #Find out what the length of the longest disease name sequence is, of all names and synonyms. This is used by get_diseases
        max_length = -1
        for entry in diseases:
            if entry['name'] not in GARD_dict.keys():
                s = entry['name'].lower().strip()
                if s not in STOPWORDS and len(s)>5:
                    GARD_dict[s] = entry['gard_id']
                    #compare length
                    max_length = max(max_length,len(s.split()))

            if entry['synonyms']:
                for synonym in entry['synonyms']:
                    if synonym not in GARD_dict.keys():
                        s = synonym.lower().strip()
                        if s not in STOPWORDS and len(s)>5:
                            GARD_dict[s] = entry['gard_id']
                            max_length = max(max_length,len(s.split()))
                            
        self.GARD_id_list = GARD_id_list
        self.GARD_dict = GARD_dict
        self.max_length = max_length
    
    def __str__(self) -> str:
        return '''Instantiation: rd_identify = GARD_Search()
                  Calling: diseases, ids = rd_identify(text) 
                  Autosearch or get disease names from GARD ID: search_terms = rd_identify.autosearch(searchterm)
                  GARD ID List: rd_identify.GARD_id_list
                  Disease Dictionary: rd_identify.GARD_dict
               '''
    
    def __call__(self, sentence:str) -> Tuple[List[str], List[str]]:
        return self.get_diseases(sentence)
    
    #Works much faster if broken down into sentences.
    #compares every phrase in a sentence to see if it matches anything in the GARD dictionary of diseases.
    def get_diseases(self, sentence:str) -> Tuple[List[str], List[str]]:   
        tokens = [s.lower().strip() for s in nltk_tokenize.word_tokenize(sentence)]
        diseases = []
        ids = []
        i=0
        #Iterates through every word, builds string that is max_length or less to compare.
        while i <len(tokens):
            #Find out the length of the comparison string, either max_length or less. This brings algorithm from O(n^2) to O(n) time
            compare_length = min(len(tokens)-i, self.max_length)

            #Compares longest sequences first and goes down until there is a match
            #print('(start compare_length)',compare_length)
            while compare_length>0:
                s = ' '.join(tokens[i:i+compare_length])
                if s.lower() in self.GARD_dict.keys():
                    diseases.append(s)
                    ids.append(self.GARD_dict[s.lower()])
                    #Need to skip over the next few indexes
                    i+=compare_length-1
                    break
                else:
                    compare_length-=1
            i+=1
        return diseases,ids
    
    #Given a GARD ID of form 'GARD:0000001', this will return all of the names of the disease
    def get_names_from_id(self, gard_id):
        return [k for k,v in self.GARD_dict.items() if v==gard_id]
    
    #Can search by 7-digit GARD_ID, 12-digit "GARD:{GARD_ID}", matched search term, or arbitrary search term
    #Returns list of terms to search by
    # search_term_list = autosearch(search_term, GARD_dict)
    def autosearch(self, searchterm:Union[str,int], matching=2) -> List[str]:
        #comparisons below only handly strings, allows int input
        if type(searchterm) is not str:
            searchterm = str(searchterm)

        #for the disease names to match
        searchterm = searchterm.lower()

        while matching>=1:
            #search in form of 'GARD:0000001'
            if 'gard:' in searchterm and len(searchterm)==12:
                searchterm = searchterm.replace('gard:','GARD:')
                l = self.get_names_from_id(searchterm)
                l.sort(reverse=True, key=lambda x:len(x))
                if len(l)>0:
                    print("SEARCH TERM MATCHED TO GARD DICTIONARY. SEARCHING FOR: ",l)
                    return l

            #can take int or str of digits of variable input
            #search in form of 777 or '777' or '00777' or '0000777'
            elif searchterm[0].isdigit() and searchterm[-1].isdigit():
                if len(searchterm)>7:
                    raise ValueError('GARD ID IS NOT VALID. RE-ENTER SEARCH TERM')
                searchterm = 'GARD:'+'0'*(7-len(str(searchterm)))+str(searchterm)
                l = self.get_names_from_id(searchterm)
                l.sort(reverse=True, key=lambda x:len(x))
                if len(l)>0:
                    print("SEARCH TERM MATCHED TO GARD DICTIONARY. SEARCHING FOR: ",l)
                    return l

            #search in form of 'mackay shek carr syndrome' and returns all synonyms ('retinal degeneration with nanophthalmos, cystic macular degeneration, and angle closure glaucoma', 'retinal degeneration, nanophthalmos, glaucoma', 'mackay shek carr syndrome')
            #considers the GARD ID as the lemma, and the search term as one form. maps the form to the lemma and then uses that lemma to find all related forms in the GARD dict. 
            elif searchterm in self.GARD_dict.keys():
                l = self.get_names_from_id(searchterm)
                l.sort(reverse=True, key=lambda x:len(x))
                print("SEARCH TERM MATCHED TO GARD DICTIONARY. SEARCHING FOR: ",l)
                return l

            else:
                #This can be replaced with some other common error in user input that is easily fixed
                searchterm = searchterm.replace('-',' ')
                searchterm = searchterm.replace("'s","")
                return self.autosearch(searchterm, matching-1)
        print("SEARCH TERM DID NOT MATCH TO GARD DICTIONARY. SEARCHING BY USER INPUT")
        return [searchterm]

    # Return a random GARD_ID Search Term list
    def random_disease(self) -> List[str]:
        import random
        gard_id = random.choice(self.GARD_id_list)
        return self.autosearch(gard_id)

# %%
gard_info = GARD_Search()

# %%
print(gard_info)
# Out:
# Instantiation: rd_identify = GARD_Search()
#                   Calling: diseases, ids = rd_identify(text)
#                   Autosearch or get disease names from GARD ID: search_terms = rd_identify.autosearch(searchterm)
#                   GARD ID List: rd_identify.GARD_id_list
#                   Disease Dictionary: rd_identify.GARD_dict

# %%
GARD_id_dict = {gard_id:gard_info.get_names_from_id(gard_id) for gard_id in gard_info.GARD_id_list}

# %% [markdown]
# Logic of scoring
#
# Score1:
# ```
# if same_cluster:
#     score1 = 5
# else:
#     score1 =0
#
# ```
# Score 2:
# ```
# length_comparison = gard_info.max_length*2
#
# if same_cluster:
#     score2 = 5
# else:
#     score2 = 3*(length_comparison-len(
#     nltk_tokenize.word_tokenize(disease_name1))-len(
#     nltk_tokenize.word_tokenize(disease_name2))
#     )/length_comparison
# ```

# %%
thousand_dataset_dict = {
               "split":[],
               "sid":[],
               "score1":[],
               "score2":[],
               "term1":[],
               "gard_id1":[],
               "term2":[],
               "gard_id2":[],
              }

# %%
multiple_names = {k:v for k,v in GARD_id_dict.items() if len(v)>1}
single_names = {k:v for k,v in GARD_id_dict.items() if len(v)<2}

# %%
multiple_names
# Out:
# {'GARD:0000001': ['gracile syndrome',
#   'finnish lactic acidosis with hepatic hemosiderosis',
#   'fellman syndrome',
#   'growth retardation, aminoaciduria, cholestasis, iron overload, lactic acidosis and early death',
#   'finnish lethal neonatal metabolic syndrome',
#   'fellman disease',
#   'growth delay-aminoaciduria-cholestasis-iron overload-lactic acidosis-early death syndrome',
#   'growth restriction-aminoaciduria-cholestasis-iron overload-lactic acidosis-early death syndrome'],
#  'GARD:0000003': ['ablepharon macrostomia syndrome',
#   'congenital ablepharon, absent eyelashes/eyebrows, macrostomia, auricular, nasal, genital and other systemic anomalies'],
#  'GARD:0000004': ['acanthocheilonemiasis',
#   'dipetalonemiasis',
#   'dipetalonema infections',
#   'acanthocheilonema perstans infection',
#   'mansonella perstans'],
#  'GARD:0000005': ['abetalipoproteinemia',
#   'bassen kornzweig syndrome',
#   'microsomal triglyceride transfer protein deficiency disease',
#   'microsomal triglyceride transfer protein deficiency',
#   'abetalipoproteinemia neuropathy',
#   'apolipoprotein b deficiency',
#   'betalipoprotein deficiency disease',
#   'congenital betalipoprotein deficiency syndrome',
#   'mtp deficiency',
#   'bassen-kornzweig disease',
#   'homozygous familial hypobetalipoproteinemia'],
#  'GARD:0000006': ['acromesomelic dysplasia', 'acromesomelic dwarfism'],
#  'GARD:0000007': ['acromicric dysplasia', 'acromicric skeletal dysplasia'],
#  'GARD:0000008': ['agnosia',
#   'primary visual agnosia',
#   'monomodal visual amnesia',
#   'visual amnesia'],
#  'GARD:0000011': ['alternating hemiplegia of childhood',
#   'alternating hemiplegia syndrome',
#   'alternating hemiplegia'],
#  'GARD:0000012': ['hypersensitivity pneumonitis',
#   'allergic interstitial pneumonitis',
#   'alveolitis, extrinsic allergic',
#   'allergic pneumonitis',
#   'extrinsic allergic pneumonia hypersensitivity pneumonitis'],
#  'GARD:0000013': ['gillespie syndrome',
#   'aniridia, cerebellar ataxia and mental deficiency'],
#  'GARD:0000016': ['oculomotor apraxia cogan type',
#   'congenital oculomotor apraxia',
#   "cogan's syndrome type 2",
#   'saccade initiation failure congenital'],
#  'GARD:0000017': ['arachnoid cysts',
#   'arachnoid cysts, intracranial',
#   'intracranial arachnoid cysts'],
#  'GARD:0000022': ['bjornstad syndrome',
#   'pili torti and nerve deafness',
#   'pili torti-sensorineural hearing loss',
#   'deafness and pili torti, bjornstad type'],
#  'GARD:0000026': ['cat eye syndrome',
#   'schmid-fraccaro syndrome',
#   'chromosome 22 partial tetrasomy',
#   'inv dup(22)(q11)'],
#  'GARD:0000027': ['cat scratch disease',
#   'bartonellosis due to bartonella henselae infection',
#   'cat scratch fever'],
#  'GARD:0000028': ['catel manzke syndrome',
#   'hyperphalangy-clinodactyly of index finger with pierre robin syndrome',
#   'pierre robin syndrome with hyperphalangy and clinodactyly',
#   'palatodigital syndrome catel-manzke type',
#   'index finger anomaly with pierre robin syndrome'],
#  'GARD:0000029': ['charge syndrome',
#   'coloboma, heart anomaly, choanal atresia, retardation, genital and ear anomalies',
#   'charge association',
#   'hall-hittner syndrome'],
#  'GARD:0000030': ['cholecystitis',
#   'gallstone cholecystitis',
#   'acalculous cholecystitis'],
#  'GARD:0000031': ['serpiginous choroiditis',
#   'geographic choroiditis',
#   'geographic helicoid peripapillary choroidopathy (ghpc)',
#   'geographic serpiginous choroiditis',
#   'peripapillary choriopathy',
#   'serpiginous choroidopathy'],
#  'GARD:0000035': ['chromosome 18p tetrasomy',
#   'tetrasomy 18p',
#   'tetrasomy chromosome 18p',
#   'isochromosome 18p'],
#  'GARD:0000037': ['partial deletion of the short arm of chromosome 3',
#   'partial deletion 3p',
#   '3p partial deletion',
#   'partial monosomy 3p',
#   'partial deletion of chromosome 3p',
#   'partial monosomy of chromosome 3p',
#   'partial monosomy of the short arm of chromosome 3'],
#  'GARD:0000039': ['wt limb blood syndrome',
#   'wt syndrome',
#   'radial-ulnar hypoplasia with bone marrow failure and/or leukemia'],
#  'GARD:0000042': ['tetrasomy 9p',
#   'chromosome 9p tetrasomy',
#   'tetrasomy of short arm of chromosome 9',
#   'mosaic tetrasomy 9p'],
#  'GARD:0000043': ['mosaic trisomy 9',
#   'mosaic trisomy chromosome 9',
#   'trisomy 9 mosaicism'],
#  'GARD:0000044': ['haim-munk syndrome',
#   'keratosis palmoplantaris with periodontopathia and onychogryposis',
#   'cochin jewish disorder'],
#  'GARD:0000045': ['congenital varicella syndrome',
#   'fetal effects of chickenpox',
#   'fetal varicella infection',
#   'fetal varicella zoster syndrome',
#   'fetal effects of varicella zoster virus',
#   'varicella embryopathy',
#   'varicella virus antenatal infection'],
#  'GARD:0000046': ['corticobasal degeneration',
#   'cortical-basal ganglionic degeneration',
#   'cortico-basal ganglionic degeneration (cbgd)',
#   'corticobasal syndrome'],
#  'GARD:0000047': ['crigler najjar syndrome, type 1',
#   'crigler-najjar syndrome, type i'],
#  'GARD:0000048': ['cytochrome c oxidase deficiency',
#   'complex 4 mitochondrial respiratory chain deficiency',
#   'deficiency of mitochondrial respiratory chain complex4',
#   'cox deficiency',
#   'complex iv deficiency',
#   'mitochondrial complex iv deficiency'],
#  'GARD:0000049': ['de barsy syndrome',
#   'corneal clouding, cutis laxa and intellectual disability',
#   'progeroid syndrome of de barsy',
#   'cutis laxa growth deficiency syndrome',
#   'progeroid syndrome, de barsy type',
#   'cutis laxa-corneal clouding-intellectual disability syndrome'],
#  'GARD:0000054': ['duodenal atresia', 'duodenal stenosis'],
#  'GARD:0000059': ['spinocerebellar ataxia 34',
#   'giroux barbeau syndrome',
#   'erythrokeratodermia - ataxia',
#   'erythrokeratodermia with ataxia'],
#  'GARD:0000060': ['iridocorneal endothelial syndrome', 'ice syndrome'],
#  'GARD:0000061': ['femoral facial syndrome',
#   'femoral dysgenesis, bilateral',
#   'femoral hypoplasia unusual facies syndrome'],
#  'GARD:0000062': ['filippi syndrome',
#   'syndactyly type i with microcephaly and mental retardation',
#   'unusual facial appearance, microcephaly, growth and mental retardation and syndactyly',
#   'type 1 syndactyly-microcephaly-intellectual disability syndrome'],
#  'GARD:0000064': ['fountain syndrome',
#   'intellectual disability, deafness, skeletal abnormalities, coarse face with full lips',
#   'deafness, skeletal dysplasia, lip granuloma'],
#  'GARD:0000065': ['galloway-mowat syndrome',
#   'galloway mowat syndrome',
#   'galloway syndrome',
#   'microcephaly nephrosis syndrome',
#   'nephrosis neuronal dysmigration syndrome',
#   'hiatal hernia-microcephaly-nephrosis, galloway type',
#   'microcephaly, hiatal hernia, and nephrotic syndrome'],
#  'GARD:0000066': ['gorlin chaudhry moss syndrome',
#   'craniofacial dysostosis, patent ductus arteriosus, hypertrichosis, hypoplasia of labia majora, dental and eye anomalies',
#   'gcm syndrome',
#   'gorlin-chaudhry-moss syndrome'],
#  'GARD:0000068': ['hanhart syndrome',
#   'aglossia adactylia',
#   'hypoglossia-hypodactylia syndrome',
#   'peromelia with micrognathia'],
#  'GARD:0000069': ['hantavirus pulmonary syndrome',
#   'hantavirus',
#   'hantavirus-associated respiratory distress syndrome',
#   'four corners hantavirus'],
#  'GARD:0000070': ['hemangioma thrombocytopenia syndrome',
#   'kasabach merritt syndrome',
#   'thrombocytopenia-hemangioma syndrome',
#   'kasabach merritt phenomenon'],
#  'GARD:0000071': ['human granulocytic ehrlichiosis',
#   'human ehrlichial infection, human granulocytic type'],
#  'GARD:0000072': ['human monocytic ehrlichiosis',
#   'human ehrlichial infection, human monocytic type'],
#  'GARD:0000073': ['immunodeficiency with hyper igm type 1',
#   'x-linked hyper igm syndrome',
#   'hyper igm immunodeficiency, x-linked',
#   'hyper igm syndrome',
#   'hyper igm syndrome 1'],
#  'GARD:0000076': ['hypohidrotic ectodermal dysplasia',
#   'ectodermal dysplasia, hypohidrotic',
#   'anhidrotic ectodermal dysplasia',
#   'ectodermal dysplasia anhidrotic'],
#  'GARD:0000079': ['jansen type metaphyseal chondrodysplasia',
#   'metaphyseal chondrodysplasia murk jansen type',
#   'murk jansen type metaphyseal chondrodysplasia'],
#  'GARD:0000080': ['johanson-blizzard syndrome',
#   'nasal alar hypoplasia, hypothyroidism, pancreatic achylia and congenital deafness'],
#  'GARD:0000081': ['juberg marsidi syndrome',
#   'intellectual disability, x-linked with growth delay, deafness, microgenitalism',
#   'juberg-marsidi intellectual disability syndrome',
#   'x-linked hypogonadism gynecomastia intellectual disability',
#   'x-linked intellectual disability-hypotonic facies syndrome 1',
#   'juberg-marsidi syndrome',
#   'intellectual disability, x-linked, with growth retardation, deafness, and microgenitalism'],
#  'GARD:0000082': ['kbg syndrome',
#   'short stature, characteristic facies, macrodontia, mental retardation, and skeletal anomalies'],
#  'GARD:0000083': ['kenny-caffey syndrome type 2',
#   'dwarfism, cortical thickening of tubular bones and transient hypocalcemia',
#   'kenny-caffey syndrome, autosomal dominant'],
#  'GARD:0000084': ['congenital generalized lipodystrophy type 1',
#   'berardinelli-seip congenital lipodystrophy type 1',
#   'agpat2-related brunzell syndrome'],
#  'GARD:0000085': ['thanatophoric dysplasia',
#   'dwarfism thanatophoric',
#   'thanatophoric dwarfism'],
#  'GARD:0000086': ['chudley-mccullough syndrome',
#   'deafness, sensorineural, with partial agenesis of the corpus callosum and arachnoid cysts',
#   'deafness, bilateral sensorineural, and hydrocephalus due to foramen of monro obstruction'],
#  'GARD:0000087': ['lenz microphthalmia syndrome',
#   'microphthalmia syndromic 1',
#   'mcops1',
#   'lenz dysplasia',
#   'syndromic microphthalmia type 1',
#   'maa (formerly)',
#   'microphthalmia or anophthalmos with associated anomalies (formerly)',
#   'microphthalmia lenz type'],
#  'GARD:0000088': ['leri pleonosteosis',
#   'leri type pleonosteosis',
#   "leri's pleonosteosis",
#   'pleonosteosis leri type'],
#  'GARD:0000089': ['gastric non-hodgkin lymphoma',
#   'non-hodgkins gastric lymphoma',
#   'stomach lymphoma, non-hodgkins type'],
#  'GARD:0000092': ['meleda disease',
#   'keratosis palmoplantaris transgradiens of siemens',
#   'mal de meleda'],
#  'GARD:0000093': ['monilethrix', 'nodose hair'],
#  'GARD:0000094': ['mucolipidosis type 4',
#   'berman syndrome',
#   'ganglioside neuraminidase deficiency',
#   'ganglioside sialidase deficiency',
#   'mucolipidosis type iv'],
#  'GARD:0000095': ['mulibrey nanism',
#   'muscle-liver-brain-eye nanism',
#   'pericardial constriction and growth failure',
#   'perheentupa syndrome'],
#  'GARD:0000102': ['neu laxova syndrome',
#   '3-phosphoglycerate dehydrogenase deficiency, neonatal form',
#   'neu-laxova syndrome'],
#  'GARD:0000104': ['ochoa syndrome',
#   'hydronephrosis with peculiar facial expression',
#   'urofacial syndrome',
#   'inverted smile and occult neuropathic bladder',
#   'partial facial palsy with urinary abnormalities',
#   "urofacial ochoa's syndrome"],
#  'GARD:0000105': ['oculocerebral syndrome with hypopigmentation',
#   'cross syndrome',
#   'kramer syndrome',
#   'oculocerebral hypopigmentation syndrome',
#   'hypopigmentation oculocerebral syndrome cross type'],
#  'GARD:0000106': ['oculocerebrocutaneous syndrome',
#   'delleman syndrome',
#   'delleman oorthuys syndrome',
#   'orbital cyst with cerebral and focal dermal malformations',
#   'occ syndrome',
#   'oculo-cerebro-cutaneous syndrome'],
#  'GARD:0000108': ['adult polyglucosan body disease',
#   'polyglucosan body disease, adult form',
#   'polyglucosan body neuropathy, adult form'],
#  'GARD:0000109': ['progressive osseous heteroplasia',
#   'familial ectopic ossification',
#   'ectopic ossification familial type'],
#  'GARD:0000111': ['recurrent respiratory papillomatosis',
#   'juvenile laryngeal papilloma',
#   'laryngeal papilloma, recurrent',
#   'juvenile-onset recurrent respiratory papillomatosis (type)',
#   'jorrp (type)',
#   'adult-onset recurrent respiratory papillomatosis (type)',
#   'aorrp (type)',
#   'respiratory papillomatosis, recurrent'],
#  'GARD:0000112': ['respiratory distress syndrome, infant',
#   'hyaline membrane disease',
#   'infantile respiratory distress syndrome',
#   'neonatal respiratory distress syndrome',
#   'rds - infants'],
#  'GARD:0000113': ['retinopathy, arteriosclerotic', 'arteriosclerosis, retina'],
#  'GARD:0000114': ['x-linked charcot-marie-tooth disease type 5',
#   'charcot-marie-tooth neuropathy x type 5',
#   'rosenberg-chutorian syndrome',
#   'optic atrophy, polyneuropathy, and deafness',
#   'optic atrophy, sensorineural hearing loss and polyneuropathy',
#   'familial opticoacoustic nerve degeneration and polyneuropathy'],
#  'GARD:0000116': ['schindler disease type 1',
#   'neuroaxonal dystrophy, schindler type',
#   'alpha-n-acetylgalactosaminidase deficiency, type 1',
#   'naga deficiency, type 1',
#   'schindler disease type i'],
#  'GARD:0000117': ['schinzel giedion syndrome',
#   'schinzel giedion midface-retraction syndrome',
#   'schinzel-giedion syndrome'],
#  'GARD:0000118': ['ulnar-mammary syndrome',
#   'schinzel syndrome',
#   'ulnar-mammary syndrome of pallister'],
#  'GARD:0000120': ['sennetsu fever',
#   'human ehrlichial infection, sennetsu type'],
#  'GARD:0000121': ['facial ectodermal dysplasia',
#   'setleis syndrome',
#   'bitemporal forceps marks syndrome',
#   'focal facial dermal dysplasia type 2',
#   'ffdd type 2'],
#  'GARD:0000122': ['singleton-merten syndrome',
#   'merten-singleton syndrome',
#   'sm syndrome',
#   'widened medullary cavities of bone, aortic calcification, abnormal dentition, and muscular weakness',
#   'syndrome of widened medullary cavities of the metacarpals and phalanges, aortic calcification and abnormal dentition',
#   'singleton-merten dysplasia'],
#  'GARD:0000124': ['allain-babin-demarquez syndrome',
#   'acro cephalo synostosis',
#   'craniosynostosis synostoses hypertensive nephropathy'],
#  'GARD:0000125': ['acrokeratoelastoidosis of costa',
#   'collagenous plaques of hand and feet',
#   'palmoplantar keratoderma, punctate type 3'],
#  'GARD:0000130': ['florid cystic endosalpingiosis of the uterus',
#   'cystic endosalpingiosis of the uterus'],
#  'GARD:0000132': ['primary cutaneous amyloidosis',
#   'primary localized cutaneous amyloidosis',
#   'lichen amyloidosis familial',
#   'amyloidosis familial cutaneous lichen',
#   'amyloidosis 9',
#   'amyloidosis ix'],
#  'GARD:0000133': ['aganglionosis, total intestinal',
#   "rare form of hirschsprung's disease",
#   'aganglionosis, total colonic',
#   'near-total intestinal aganglionosis'],
#  'GARD:0000134': ['spondyloepimetaphyseal dysplasia strudwick type',
#   'dappled metaphysis syndrome',
#   'strudwick syndrome',
#   'smed strudwick type',
#   'smed type 1'],
#  'GARD:0000136': ['dextrocardia with unusual facies and microphthalmia',
#   'aughton syndrome',
#   'dextrocardia, microphthalmia, cleft palate, choreoathetosis and mental retardation'],
#  'GARD:0000137': ['dandy-walker malformation with nasopharyngeal teratoma and diaphragmatic hernia',
#   'aughton sloan milad syndrome'],
#  'GARD:0000139': ['atrial myxoma, familial', 'intracardiac myxoma'],
#  'GARD:0000140': ['small intestine atresia',
#   'congenital atresia of the small intestine'],
#  'GARD:0000143': ['hairy elbows', 'hypertrichosis cubiti'],
#  'GARD:0000144': ['mac dermot winter syndrome',
#   'prominent glabella microcephaly hypogenitalism',
#   'macdermot-winter syndrome'],
#  'GARD:0000147': ['macrocephaly, benign familial',
#   'benign familial macrocephaly',
#   'cole-hughes syndrome',
#   'benign familial megalencephaly'],
#  'GARD:0000149': ['prostatic malacoplakia associated with prostatic abscess',
#   'prostatic malacoplakia with prostatic and seminal vesicle abscess'],
#  'GARD:0000150': ['sammartino decreccio syndrome',
#   'superficial annular corneal dystrophy, ichthyosis nigrans, microcephaly and mild mental subnormality'],
#  'GARD:0000151': ['samson gardner syndrome',
#   'craniosynostosis, microcephaly, hydrancephaly, humero-radial synostosis, and thumb aplasia'],
#  'GARD:0000152': ['samson viljoen syndrome',
#   'lateral facial cleft, cleft lip and palate, anophthalmia, microtia, clavicular agenesis and asternia'],
#  'GARD:0000153': ['sanderson fraser syndrome',
#   'proptosis, robin association, clenched hands, and multiple abnormalities'],
#  'GARD:0000154': ['sandhaus ben-ami syndrome',
#   'patella hypoplasia skeletal malformations'],
#  'GARD:0000155': ['laurin-sandrow syndrome',
#   'fibula ulna duplication tibia radius absence',
#   'sandrow syndrome',
#   'mirror hands and feet with nasal defects',
#   'tetramelic mirror-image polydactyly',
#   'laurin sandrow syndrome'],
#  'GARD:0000156': ['muscle eye brain disease',
#   'muscle-eye-brain disease',
#   'muscular dystrophy-dystroglycanopathy congenital with brain and eye anomalies a3'],
#  'GARD:0000157': ['santos mateus leal syndrome',
#   'hirschsprung disease, deafness and polydactyly',
#   'hirschsprung disease associated with polydactyly, unilateral renal agenesis, hypertelorism, and congenital deafness'],
#  'GARD:0000158': ['sarcosinemia',
#   'sarcosine dehydrogenase complex deficiency',
#   'sard deficiency',
#   'hypersarcosinemia',
#   'sardh deficiency'],
#  'GARD:0000159': ['scalp ear nipple syndrome',
#   'hereditary syndrome of lumpy scalp, odd ears and rudimentary nipples',
#   'sen syndrome',
#   'finlay-marks syndrome',
#   'scalp-ear-nipple syndrome'],
#  'GARD:0000160': ['satoyoshi syndrome',
#   'komuragaeri disease',
#   'muscle spasms, intermittent with alopecia, diarrhea and skeletal abnormalities'],
#  'GARD:0000162': ['say syndrome',
#   'cleft palate large ears small head',
#   'cleft palate, microcephaly, large ears, and short stature',
#   'say barber hobbs syndrome'],
#  'GARD:0000169': ['schneckenbecken dysplasia',
#   'chondrodysplasia lethal neonatal with snail like pelvis'],
#  'GARD:0000171': ['le marec bracq picaud syndrome',
#   'complex malformation syndrome with brachymesomelia'],
#  'GARD:0000172': ['macrocephaly-short stature-paraplegia syndrome',
#   'volcke soekarman syndrome',
#   'volcke-soekarman syndrome'],
#  'GARD:0000173': ['macroepiphyseal dysplasia with osteoporosis, wrinkled skin, and aged appearance',
#   'mcalister coe whyte syndrome',
#   'macroepiphyseal dysplasia, mcalister coe type'],
#  'GARD:0000174': ['kuzniecky andermann syndrome',
#   'macrogyria, pseudobulbar palsy and mental retardation'],
#  'GARD:0000175': ['infantile free sialic acid storage disease',
#   'sialuria, infantile form',
#   'infantile sialic acid storage disorder'],
#  'GARD:0000176': ['macrophagic myofasciitis',
#   'macrophagic myofasciitis, childhood'],
#  'GARD:0000177': ['macrosomia with lethal microphthalmia',
#   'teebi al-saleh hassoon syndrome',
#   'macrosomia microphthalmia cleft palate'],
#  'GARD:0000178': ['momo syndrome',
#   'macrosomia, obesity, macrocephaly, ocular abnormalities',
#   'macrocrania, obesity, ocular abnormalities (retinal coloboma and nystagmus)'],
#  'GARD:0000179': ['macrothrombocytopenia progressive deafness',
#   'brodie chole griffin syndrome'],
#  'GARD:0000180': ['myh9 related thrombocytopenia',
#   'myh9 related disorders',
#   'sebastian syndrome (subtype)',
#   'may-hegglin anomaly (subtype)',
#   'fechtner syndrome (subtype)',
#   'epstein syndrome (subtype)',
#   'macrothrombocytopenia and granulocyte inclusions with or without nephritis or sensorineural hearing loss',
#   'myh9-rd',
#   'myh9-related disease',
#   'myh9-related disorder',
#   'myh9-related syndrome',
#   'myh9-related syndromic thrombocytopenia'],
#  'GARD:0000181': ['stargardt disease',
#   'stargardt macular dystrophy',
#   'juvenile onset macular degeneration'],
#  'GARD:0000182': ['best vitelliform macular dystrophy',
#   'best disease',
#   'best macular dystrophy',
#   'macular degeneration, polymorphic vitelline',
#   'vitelliform macular dystrophy type 2',
#   'early-onset vitelliform macular dystrophy',
#   'juvenile-onset vitelliform macular dystrophy',
#   'polymorphic vitelline macular degeneration'],
#  'GARD:0000184': ['yellow nail syndrome', 'lymphedema with yellow nails'],
#  'GARD:0000185': ['y chromosome infertility',
#   'male sterility due to y-chromosome deletions',
#   'deleted in azoospermia',
#   'y chromosome microdeletions'],
#  'GARD:0000188': ['n acetyltransferase deficiency',
#   'n acetyltransferase 1 deficiency',
#   'nat1 deficiency',
#   'arylamine n-acetyltransferase 1',
#   'acetyl-coa:arylamine n-acetyltransferase'],
#  'GARD:0000189': ['elliott ludman teebi syndrome',
#   'multiple congenital anomalies, severe psychomotor retardation and symmetrical circumferential skin creases of arms and legs'],
#  'GARD:0000191': ['kashani strom utley syndrome',
#   'pulmonary aortic stenosis obstructive uropathy',
#   'hypoplastic pulmonary arteries and aorta with obstructive uropathy'],
#  'GARD:0000192': ['karandikar maria kamble syndrome',
#   'cataract mental retardation anal atresia urinary defects',
#   'congenital cataract with multiple congenital anomalies in a sibship'],
#  'GARD:0000193': ['opitz g/bbb syndrome',
#   'hypospadias-dysphagia, syndrome',
#   'opitz-frias syndrome',
#   'g syndrome',
#   'opitz-g syndrome, type 2',
#   'hypertelorism hypospadias syndrome',
#   'hypertelorism with esophageal abnormality and hypospadias',
#   'bbb syndrome',
#   'telecanthus with associated abnormalities',
#   'opitz bbbg syndrome',
#   'gbbb syndrome'],
#  'GARD:0000194': ['gamma aminobutyric acid transaminase deficiency',
#   'gaba transaminase deficiency',
#   'gamma aminobutyrate transaminase deficiency',
#   '4 alpha aminobutyrate transaminase deficiency'],
#  'GARD:0000195': ['hyperkalemic periodic paralysis',
#   'gamstorp disease',
#   'gamstorp episodic adynamy',
#   'adynamia episodica hereditaria with or without myotonia',
#   'sodium channel muscle disease'],
#  'GARD:0000196': ["st anthony's fire", 'ergotism'],
#  'GARD:0000198': ['spinal muscular atrophy type 3',
#   'muscular atrophy, juvenile',
#   'kugelberg-welander syndrome',
#   'spinal muscular atrophy, mild childhood and adolescent form'],
#  'GARD:0000199': ['cardiac hydatid cysts with intracavitary expansion',
#   'cardiac hydatidosis'],
#  'GARD:0000200': ['central serous chorioretinopathy',
#   'central serous chorioretinopathy after bone marrow transplantation',
#   'central serous choroidopathy'],
#  'GARD:0000201': ['ascher syndrome',
#   'double upper lip, blepharochalasis and enlargement of the thyroid',
#   "ascher's syndrome",
#   'blepharochalasis - double lip',
#   'blepharochalasis and double lip',
#   'blepharochalasis-double lip syndrome'],
#  'GARD:0000204': ["dieterich's disease",
#   'avascular necrosis of the metacarpal head',
#   'dieterich disease'],
#  'GARD:0000207': ['alveolar echinococcosis', 'echinococcosis'],
#  'GARD:0000208': ['giant mammary hamartoma', 'giant hamartoma of the breast'],
#  'GARD:0000210': ['ruzicka goerz anton syndrome',
#   'ichthyosis deafness mental retardation skeletal anomalies',
#   'ichthyosis congenita, neurosensory deafness, oligophrenia, dental aplasia, brachydactyly, clinodactyly, accessory cervical ribs and thyroid carcinoma'],
#  'GARD:0000212': ['rutherfurd syndrome',
#   'gingival hypertrophy corneal dystrophy',
#   'corneal dystrophy with gum hypertrophy'],
#  'GARD:0000213': ['axial mesodermal dysplasia spectrum',
#   'russell weaver bull syndrome'],
#  'GARD:0000215': ['familial caudal dysgenesis',
#   'caudal dysgenesis familial type',
#   'rudd-klimek syndrome'],
#  'GARD:0000216': ['rozin hertz goodman syndrome',
#   'camptodactyly, joint contractures, facial skeletal defects',
#   'camptodactyly, myopia, and fibrosis of the medial rectus muscle of eye'],
#  'GARD:0000217': ['roy maroteaux kremp syndrome',
#   'metaphyseal modeling abnormality, skin lesions, and spastic paraplegia'],
#  'GARD:0000218': ['rotor syndrome',
#   'hyperbilirubinemia, rotor type',
#   'rotor-type hyperbilirubinemia'],
#  'GARD:0000220': ['peripartum cardiomyopathy',
#   'postpartum cardiomyopathy',
#   "meadows' syndrome"],
#  'GARD:0000221': ['dilated cardiomyopathy',
#   'idiopathic dilated cardiomyopathy'],
#  'GARD:0000223': ['acoustic neuroma',
#   'acoustic neurilemoma',
#   'acoustic neurinoma',
#   'cerebellopontine angle tumor',
#   'vestibular schwannoma',
#   'neurinoma of the acoustic nerve',
#   'acoustic tumor'],
#  'GARD:0000224': ['radio renal syndrome', 'radio-renal syndrome'],
#  'GARD:0000226': ['rabson-mendenhall syndrome',
#   'pineal hyperplasia, insulin-resistant diabetes mellitus, and somatic abnormalities',
#   'mendenhall syndrome',
#   'insr-related severe syndromic insulin resistance'],
#  'GARD:0000229': ['gomez lopez hernandez syndrome',
#   'cerebellotrigeminal-dermal dysplasia',
#   'cerebellotrigeminal dermal dysplasia',
#   'gomez-lopez-hernández syndrome',
#   'cerebellotrigeminal-dermal dysplasia syndrome',
#   'craniosynostosis-alopecia-brain defect syndrome'],
#  'GARD:0000230': ['microcephaly deafness syndrome',
#   'kawashima tsuji syndrome',
#   'syndrome of microcephaly, deafness/malformed ears, mental retardation and peculiar facies'],
#  'GARD:0000231': ['leukoencephalopathy with vanishing white matter',
#   'childhood ataxia with diffuse central nervous system hypomyelination',
#   'cach syndrome',
#   'cach/vwm syndrome',
#   'myelinosis centralis diffusa',
#   'cree leukoencehalopathy',
#   'childhood ataxia with central nervous system hypomyelination/vanishing white matter',
#   'cach/vwm',
#   'vanishing white matter leukodystrophy',
#   'vanishing white matter disease'],
#  'GARD:0000232': ['medullary sponge kidney',
#   'cacchi ricci disease',
#   'precalyceal canalicular ectasia',
#   'cacchi-ricci syndrome',
#   'sponge kidney',
#   'cystic dilatation of renal collecting tubes',
#   'cacchi-ricci disease',
#   'precalicial canalicular ectasia'],
#  'GARD:0000233': ['d ercole syndrome',
#   'short stature microcephaly heart defect'],
#  'GARD:0000234': ['d-glycericacidemia',
#   'd-glycerate kinase deficiency',
#   'non ketotic hyperglycinemia syndrome'],
#  'GARD:0000236': ['daentl towsend siegel syndrome',
#   'hydrocephalus blue sclera nephropathy',
#   'familial nephrosis, hydrocephalus, thin skin, blue sclerae syndrome'],
#  'GARD:0000237': ['dahlberg borer newcomer syndrome',
#   'lymphedema hypoparathyroidism syndrome',
#   'hypoparathyroidism lymphedema syndrome'],
#  'GARD:0000238': ['odontoma dysphagia syndrome',
#   'odontomatosis (multiple odontomas) with dysphagia',
#   'boder syndrome'],
#  'GARD:0000239': ['say barber miller syndrome',
#   'microcephaly hypogammaglobulinemia abnormal immunity',
#   'microcephaly with chemotactic defect and transient hypogammaglobulinemia'],
#  'GARD:0000240': ['say carpenter syndrome',
#   'metaphyseal dysplasia hypertelorism hypospadias'],
#  'GARD:0000241': ['scalp defects postaxial polydactyly',
#   'congenital scalp defects associated with postaxial polydactyly'],
#  'GARD:0000242': ['say-field-coldwell syndrome',
#   'triphalangeal thumbs and dislocation of patella',
#   'polydactyly with triphalangeal thumbs, brachydactyly, camptodactyly, congenital dislocation of the patellas, short stature and borderline intelligence'],
#  'GARD:0000243': ['say meyer syndrome',
#   'trigonocephaly, short stature, and retarded psychomotor development',
#   'say-meyer syndrome',
#   'trigonocephaly-short stature-developmental delay syndrome'],
#  'GARD:0000246': ['schisis association', 'midline development field defects'],
#  'GARD:0000247': ['scarf syndrome',
#   'skeletal abnormalities, cutis laxa, craniostenosis, ambiguous genitalia, retardation, and facial abnormalities'],
#  'GARD:0000248': ['schaap taylor baraitser syndrome',
#   'cataracts, sensorineural deafness, hypogonadism, hypertrichosis and short stature'],
#  'GARD:0000249': ['schaefer stein oshman syndrome',
#   'dominantly inherited craniodiaphyseal dysplasia',
#   'craniodiaphyseal dysplasia, dominant'],
#  'GARD:0000250': ['schwartz jampel syndrome',
#   'schwartz jampel aberfeld syndrome',
#   'myotonic myopathy dwarfism chondrodystrophy and ocular and facial abnormalities',
#   'sja syndrome',
#   'chondrodystrophic myotonia',
#   'myotonic chondrodystrophy',
#   'myotonic myopathy, dwarfism, chondrodystrophy, ocular and facial anomalies',
#   'aberfeld syndrome',
#   'burton skeletal dysplasia',
#   'catel-hempel syndrome',
#   'dysostosis enchondralis metaepiphysaria, catel-hempel type',
#   'osteochondromuscular dystrophy',
#   'schwartz-jampel syndrome',
#   'schwartz-jampel-aberfeld syndrome'],
#  'GARD:0000253': ['schwartz cohen-addad lambert syndrome',
#   'congenital melanocytosis with myelomeningocele and hydrocephalus'],
#  'GARD:0000255': ['schlegelberger grote syndrome',
#   'triphalangeal thumbs thrombocytopathy deafness',
#   'syndrome with triphalangia of thumbs, thrombasthenia glanzmann and deafness of internal ear'],
#  'GARD:0000256': ['schrander-stumpel theunissen hulsmans syndrome',
#   'vitiligo, psychomotor retardation, cleft palate and facial dysmorphism',
#   'vitiligo vulgaris, cleft palate, somatic and psychomotor retardation and facial dysmorphism'],
#  'GARD:0000257': ['scholte syndrome',
#   'early balding, patella luxation, acromicria and hypogonadism'],
#  'GARD:0000259': ['diabetes insipidus nephrogenic mental retardation and intracerebral calcification',
#   'schofer beetz bohl syndrome'],
#  'GARD:0000262': ['neuropathy ataxia retinitis pigmentosa syndrome',
#   'narp syndrome'],
#  'GARD:0000264': ['lowry wood syndrome',
#   'epiphyseal dysplasia, microcephaly and nystagmus'],
#  'GARD:0000265': ['trichodental syndrome',
#   'trichodental dysplasia',
#   'tricho-dental syndrome',
#   'tricho-dental dysplasia'],
#  'GARD:0000267': ['nasodigitoacoustic syndrome', 'keipert syndrome'],
#  'GARD:0000269': ['ivic syndrome',
#   'instituto venezolano de investigaciones cientificas syndrome',
#   'radial ray defects, hearing impairment, external ophthalmoplegia, and thrombocytopenia',
#   'oculootoradial syndrome'],
#  'GARD:0000270': ['nicolaides-baraitser syndrome',
#   'sparse hair and mental retardation'],
#  'GARD:0000271': ['vagneur triolle ripert syndrome',
#   'hypertelorism, short midface, arachnodactyly, coloboma of iris and delayed bone age'],
#  'GARD:0000272': ['vacterl hydrocephaly',
#   'vertebral (v), anal (a), cardiac (c), tracheoesophageal (te), renal (r) and limb (l) anomalies and hydrocephaly',
#   'vacterl association with hydrocephaly'],
#  'GARD:0000274': ['woods black norbury syndrome',
#   'neonatal death immune deficiency',
#   'x-linked immunoneurological disorder'],
#  'GARD:0000276': ['eunuchoidism familial hypogonadotropic',
#   'gonadotropin deficiency familial idiopathic',
#   'familial hypogonadotropic eunuchoidism'],
#  'GARD:0000277': ['pilodental dysplasia with refractive errors',
#   'trichodental dysplasia with hyperopia'],
#  'GARD:0000279': ['hemorrhagic proctocolitis', 'haemorrhagic proctocolitis'],
#  'GARD:0000280': ['halal setton wang syndrome',
#   'hidrotic ectodermal dysplasia halal type'],
#  'GARD:0000282': ['raine syndrome',
#   'lethal osteosclerotic bone dysplasia',
#   'combination of microcephaly, exophthalmos, hypoplastic nose and midface, gum hyperplasia, cleft palate, apparently low-set ears, and osteosclerosis'],
#  'GARD:0000284': ['irons bhan syndrome',
#   'lymphedema, atrial septal defect, and characteristic facial changes',
#   'autosomal recessive syndrome of lymphedema, hydroceles, atrial septal defect, and characteristic facial changes'],
#  'GARD:0000287': ['naguib-richieri-costa syndrome',
#   'hypertelorism hypospadias polysyndactyly syndrome',
#   'acrofrontofacionasal dysostosis, severe',
#   'affn dysostosis 2',
#   'naguib syndrome'],
#  'GARD:0000288': ['hallermann-streiff syndrome',
#   'hallermann streiff syndrome',
#   'hallermann streiff francois syndrome',
#   'francois dyscephalic syndrome',
#   'françois dyscephalic syndrome',
#   'oculomandibulofacial syndrome'],
#  'GARD:0000291': ['spasticity multiple exostoses',
#   'hamann zanki schimrigk syndrome',
#   'multiple exostoses with spastic tetraparesis'],
#  'GARD:0000292': ['ichthyosis alopecia eclabion ectropion mental retardation',
#   'jagell holmgren hofer syndrome'],
#  'GARD:0000293': ['rodrigues blindness',
#   'microphthalmos, microcornea, and sclerocornea with short stature and hair and dental abnormalities'],
#  'GARD:0000294': ['enchondromatosis dwarfism deafness',
#   'wallis cremin beighton syndrome'],
#  'GARD:0000296': ['lopes gorlin syndrome',
#   'short tarsus absence of lower eyelashes'],
#  'GARD:0000298': ['lubinsky syndrome',
#   'hypogonadism cataract syndrome',
#   'cataracts and testicular failure'],
#  'GARD:0000299': ['late-onset localized junctional epidermolysis bullosa-intellectual disability syndrome',
#   'epidermolysis bullosa simplex localisata associated with anodontia, hair and nail disorders'],
#  'GARD:0000301': ['generalized resistance to thyroid hormone',
#   'thyroid hormone receptor beta',
#   'refetoff syndrome'],
#  'GARD:0000302': ['severe congenital neutropenia autosomal recessive 3',
#   'kostmann disease',
#   'agranulocytosis infantile'],
#  'GARD:0000304': ['blau syndrome',
#   'arthrocutaneouveal granulomatosis',
#   'granulomatosis, familial, blau type',
#   'granulomatous inflammatory arthritis, dermatitis, and uveitis, familial',
#   'synovitis granulomatous with uveitis and cranial neuropathies',
#   'granulomatosis, familial juvenile systemic',
#   'jabs syndrome',
#   'early onset sarcoidosis (former)'],
#  'GARD:0000305': ['deafness conductive ptosis skeletal anomalies',
#   'jackson barr syndrome'],
#  'GARD:0000306': ['camptodactyly arthropathy coxa vara pericarditis syndrome',
#   'arthropathy camptodactyly syndrome',
#   'pericarditis arthropathy camptodactyly syndrome',
#   'pac syndrome',
#   'fibrosing serositis, familial',
#   'camptodactyly arthropathy pericarditis syndrome',
#   'congenital familial hypertrophic synovitis',
#   'camptodactyly-arthropathy-coxa vara-pericarditis syndrome',
#   'arthropathy-camptodactyly syndrome',
#   'cacp syndrome',
#   'camptodactyly-arthropathy-coxa-vara-pericarditis syndrome',
#   'pericarditis-arthropathy-camptodactyly syndrome'],
#  'GARD:0000307': ['jacobsen syndrome',
#   'chromosome 11q deletion syndrome',
#   'partial 11q monosomy syndrome'],
#  'GARD:0000309': ['fibromatosis multiple non ossifying',
#   'jaffe campanacci syndrome',
#   'disseminated nonossifying fibromas in association with cafe-au-lait spots'],
#  'GARD:0000310': ['zunich neuroectodermal syndrome', 'chime syndrome'],
#  'GARD:0000311': ['saal bulas syndrome',
#   'ectrodactyly, diaphragmatic hernia, congenital heart defect, and agenesis of the corpus callosum'],
#  'GARD:0000312': ['robinow syndrome',
#   'robinow dwarfism',
#   'fetal face syndrome',
#   'acral dysostosis with facial and genital abnormalities',
#   'covesdem syndrome (formerly)',
#   'costovertebral segmentation defect with mesomelia (formerly)',
#   'mesomelic dwarfism-small genitalia syndrome',
#   'robinow-silverman-smith syndrome'],
#  'GARD:0000313': ['sabinas brittle hair syndrome',
#   'brittle hair and mental deficit',
#   'sabinas syndrome'],
#  'GARD:0000314': ['saccharopinuria', 'saccharopine dehydrogenase deficiency'],
#  'GARD:0000315': ['sackey sakati aur syndrome',
#   'aur syndrome',
#   'pancytopenia multiple congenital anomalies',
#   'multiple dysmorphic features and pancytopenia'],
#  'GARD:0000320': ['saito kuba tsuruta syndrome',
#   'fibulo ulnar hypoplasia renal anomalies',
#   'fibuloulnar aplasia or hypoplasia with renal abnormalities'],
#  'GARD:0000321': ['salcedo syndrome',
#   'nail patella like renal disease',
#   'glomerular basement membrane disease, nail-patella syndrome type'],
#  'GARD:0000322': ['senior loken syndrome',
#   'senior-loken syndrome',
#   'renal dysplasia retinal aplasia',
#   'renal-retinal syndrome',
#   'juvenile nephronophthisis with leber amaurosis',
#   'loken-senior syndrome'],
#  'GARD:0000324': ['slti salem syndrome',
#   'hypogonadotropic hypogonadism alopecia',
#   'hypogonadism and frontoparietal alopecia'],
#  'GARD:0000325': ['twin to twin transfusion syndrome',
#   'twin-to-twin transfusion syndrome',
#   'fetofetal transfusion syndrome',
#   'fetal transfusion syndrome'],
#  'GARD:0000328': ['wandering spleen',
#   'displaced spleen',
#   'drifting spleen',
#   'splenoptosis',
#   'floating spleen',
#   'splenic ptosis'],
#  'GARD:0000329': ['wells syndrome',
#   'eosinophilic cellulitis',
#   'bullous cellulitis with eosinophilia',
#   "wells' syndrome"],
#  'GARD:0000330': ['neonatal progeroid syndrome',
#   'wiedemann-rautenstrauch syndrome',
#   'progeroid syndrome neonatal',
#   'wiedemann rautenstrauch syndrome'],
#  'GARD:0000331': ['yunis-varon syndrome',
#   'cleidocranial dysplasia, micrognathia, absent thumbs, & distal aphalangia',
#   'yunis-varón syndrome',
#   'yunis varon syndrome'],
#  'GARD:0000332': ['beare-stevenson cutis gyrata syndrome',
#   'cutis gyrata syndrome of beare and stevenson',
#   'beare stevenson syndrome',
#   'cutis gyrata - acanthosis nigricans - craniosynostosis',
#   'cutis gyrata-acanthosis nigricans-craniosynostosis syndrome'],
#  'GARD:0000333': ['lymphedema-distichiasis syndrome',
#   'lymphedema with distichiasis',
#   'hereditary lymphedema-distichiasis syndrome (subtype)'],
#  'GARD:0000334': ['dyschromatosis symmetrica hereditaria 1',
#   'dyschromatosis symmetrica hereditaria',
#   'familial reticulate acropigmentation of dohi',
#   'reticulate acropigmentation of dohi',
#   'symmetric dyschromatosis of the extremities'],
#  'GARD:0000336': ['spastic paraplegia 23',
#   'spg 23',
#   'spastic paraplegia and pigmentary abnormalities',
#   'spastic paraplegia vitiligo premature graying and characteristic facies',
#   'lison syndrome',
#   'autosomal recessive spastic paraplegia type 23'],
#  'GARD:0000338': ['zerres rietschel majewski syndrome',
#   'postnatal short stature, microcephaly, severe syndactyly of hands and feet, dysmorphic face, and mental retardation'],
#  'GARD:0000339': ['zazam sheriff phillips syndrome',
#   'aniridia, ectopia lentis, abnormal upper incisors and mental retardation'],
#  'GARD:0000340': ['zadik barak levin syndrome',
#   'dermoid cysts, hypothyroidism, cleft palate and hypodontia'],
#  'GARD:0000341': ['young syndrome',
#   'azoospermia obstructive and chronic sinopulmonary infections',
#   'sinusitis-infertility syndrome',
#   'barry perkins young syndrome',
#   'azoospermia-sinopulmonary infections syndrome'],
#  'GARD:0000343': ['pontocerebellar hypoplasia type 4',
#   'encephalopathy fatal infantile with olivopontocerebellar hypoplasia'],
#  'GARD:0000344': ['pseudotrisomy 13 syndrome',
#   'holoprosencephaly polydactyly syndrome',
#   'pseudo trisomy 13 syndrome',
#   'young-maders syndrome'],
#  'GARD:0000345': ['x-linked intellectual disability - short stature – obesity',
#   'sex-linked mental retardation, short stature, obesity and hypogonadism'],
#  'GARD:0000346': ['hoyeraal hreidarsson syndrome',
#   'cerebellar hypoplasia with pancytopenia',
#   'growth retardation prenatal with progressive pancytopenia and cerebellar hypoplasia',
#   'hoyeraal-hreidarsson syndrome',
#   'progressive pancytopenia-immunodeficiency-cerebellar hypoplasia syndrome'],
#  'GARD:0000347': ['yorifuji okuno syndrome',
#   'congenital pancreatic hypoplasia with diabetes mellitus and congenital heart disease',
#   'hereditary pancreatic hypoplasia, diabetes mellitus and congenital heart disease'],
#  'GARD:0000348': ['testicular yolk sac tumor',
#   'endodermal-sinus tumor',
#   'orchidoblastoma'],
#  'GARD:0000349': ['neuroaxonal dystrophy renal tubular acidosis',
#   'maccario mena weir syndrome',
#   'cns disorder characterized by severe behavioral retardation, hypotonia, inability to talk, marked tremors, gait disturbances and inability to concentr'],
#  'GARD:0000350': ['gurrieri syndrome',
#   'mental retardation, epilepsy, short stature and skeletal dysplasia',
#   'gurrieri-sammito-bellussi syndrome'],
#  'GARD:0000351': ['osteopoikilosis and dacryocystitis',
#   'dacryocystitis osteopoikilosis',
#   'gunal seber basaran syndrome'],
#  'GARD:0000352': ['guizar vasquez sanchez manzano syndrome',
#   'dysmorphism-pectus carinatum-joint laxity syndrome',
#   'guízar vázquez-sánchez-manzano syndrome'],
#  'GARD:0000353': ['kozlowski warren fisher syndrome',
#   'cloverleaf skull generalised bone dysplasia'],
#  'GARD:0000354': ['osteopenia and sparse hair',
#   'osteopenia mental retardation sparse hair',
#   'kaler garrity stern syndrome'],
#  'GARD:0000358': ['pallister w syndrome',
#   'w syndrome',
#   'median cleft upper lip, mental retardation and pugilistic facies'],
#  'GARD:0000359': ['cranioectodermal dysplasia',
#   'levin syndrome 1',
#   'sensenbrenner syndrome'],
#  'GARD:0000360': ['abruzzo-erickson syndrome',
#   'charge like syndrome x-linked'],
#  'GARD:0000361': ['acalvaria', 'primary acalvaria'],
#  'GARD:0000362': ['alpha-thalassemia-abnormal morphogenesis',
#   'abuelo forman rubin syndrome',
#   'homozygous alpha-thalassemia, genital abnormalities, and terminal transverse limb defects'],
#  'GARD:0000363': ['acatalasemia', 'catalase deficiency', 'acatalasia'],
#  'GARD:0000364': ['arrhinia',
#   'congenital absence of the nose',
#   'nose agenesia'],
#  'GARD:0000365': ['aromatase deficiency', 'congenital estrogen deficiency'],
#  'GARD:0000366': ['arnold stickler bourne syndrome',
#   'corneal crystals myopathy and neuropathy'],
#  'GARD:0000368': ['laryngoonychocutaneous syndrome',
#   'logic syndrome',
#   'laryngo-onycho-cutaneous syndrome'],
#  'GARD:0000369': ['ayazi syndrome',
#   'choroideremia deafness obesity',
#   'choroideremia, obesity, and congenital deafness'],
#  'GARD:0000370': ['aagenaes syndrome',
#   'cholestasis lymphedema syndrome',
#   'lymphedema cholestasis syndrome'],
#  'GARD:0000371': ['qazi markouizos syndrome',
#   'dysharmonic skeletal maturation muscular fibre disproportion',
#   'hypotonia, psychomotor retardation, seizures, delayed and dysharmonic skeletal maturation, and congenital fibre type disproportion',
#   'puertorican infant hypotonia syndrome'],
#  'GARD:0000372': ['neurofibromatosis-noonan syndrome',
#   'noonan neurofibromatosis syndrome',
#   'neurofibromatosis with noonan phenotype'],
#  'GARD:0000373': ['quinquaud folliculitis decalvans',
#   'quinquaud’s disease',
#   'folliculitis decalvans'],
#  'GARD:0000374': ['zori stalker williams syndrome',
#   'pectus excavatum, macrocephaly and dysplastic nails',
#   'familial short stature, developmental delay, pectus abnormalities, distinctive facies, and dysplastic nails'],
#  'GARD:0000375': ['zlotogora syndrome',
#   'cleft lip/palate-ectodermal dysplasia syndrome',
#   'ectodermal dysplasia, cleft lip and palate, mental retardation, and syndactyly',
#   'zlotogora-ogur syndrome',
#   'clped1',
#   'cleft lip/palate-syndactyly-pili torti',
#   'syndactyly-ectodermal dysplasia-cleft/lip palate',
#   'zlotogora-zilberman-tenenbaum syndrome',
#   'cleft lip/palate-syndactyly-pili torti syndrome'],
#  'GARD:0000376': ['acheiropody',
#   'acheiropodia',
#   'acheiropody, brazilian type'],
#  'GARD:0000377': ['adactylia unilateral',
#   'terminal transverse defects of hand, unilateral'],
#  'GARD:0000378': ['johnson neuroectodermal syndrome',
#   'johnson-mcmillin syndrome',
#   'alopecia anosmia deafness hypogonadism syndrome',
#   'aadh syndrome'],
#  'GARD:0000379': ['renal tubular dysgenesis',
#   'primitive renal tubule syndrome'],
#  'GARD:0000380': ['knobloch syndrome',
#   'myopia retinal detachment encephalocele',
#   'retinal detachment-occipital encephalocele syndrome',
#   'knobloch-layer syndrome'],
#  'GARD:0000381': ['kosztolanyi syndrome',
#   'arachnodactyly, abnormal ossification and mental retardation'],
#  'GARD:0000383': ['osteopetrosis autosomal dominant type 2',
#   'autosomal dominant osteopetrosis type 2',
#   'albers-schönberg osteopetrosis'],
#  'GARD:0000384': ['adult syndrome',
#   'acro-dermato-ungual-lacrimal-tooth syndrome',
#   'acro dermato ungual lacrimal tooth syndrome'],
#  'GARD:0000385': ['laband syndrome',
#   'zimmerman laband syndrome',
#   'gingival fibromatosis, abnormal fingers, fingernails, nose and ears, and splenomegaly',
#   'fibromatosis gingival, hepatosplenomegaly other anomalies'],
#  'GARD:0000386': ['tetraamelia-multiple malformations syndrome',
#   'zimmer taub sova syndrome',
#   'zimmer phocomelia'],
#  'GARD:0000387': ['zap-70 deficiency',
#   'zeta-associated-protein 70 deficiency',
#   'severe combined immunodeficiency due to zap70 deficiency'],
#  'GARD:0000390': ['worth type autosomal dominant osteosclerosis',
#   'osteosclerosis, autosomal dominant',
#   'endosteal hyperostosis, autosomal dominant',
#   'osteosclerosis, autosomal dominant, worth type',
#   'worth syndrome',
#   'endosteal hyperostosis, worth type',
#   'autosomal dominant osteosclerosis, worth type',
#   'hyperostosis corticalis generalisata, benign form of worth with torus palatinus'],
#  'GARD:0000391': ['osteomesopyknosis', 'axial osteosclerosis'],
#  'GARD:0000393': ['tungiasis',
#   'tunga penetrans',
#   't penetrans',
#   'sarcopsylla penetrans',
#   's penetrans',
#   'chigger flea'],
#  'GARD:0000394': ['radioulnar synostosis-microcephaly-scoliosis syndrome',
#   'tsukahara syndrome',
#   'tsukahara syndrome of radioulnar synostosis, short stature, microcephaly, scoliosis, and mental retardation',
#   'giuffré-tsukahara syndrome'],
#  'GARD:0000395': ['retinal degeneration with nanophthalmos, cystic macular degeneration, and angle closure glaucoma',
#   'retinal degeneration, nanophthalmos, glaucoma',
#   'mackay shek carr syndrome'],
#  'GARD:0000396': ['tularemia',
#   'francisella tularensis infection',
#   'deerfly fever',
#   'rabbit fever',
#   'pahvant valley plague',
#   'ohara disease',
#   'yatobyo (japan)',
#   'lemming fever'],
#  'GARD:0000398': ['bagatelle cassidy syndrome',
#   'macrocephaly short limbs deafness',
#   'macrocephaly, hypertelorism, short limbs, hearing loss, and developmental delay'],
#  'GARD:0000399': ['46,xx testicular disorder of sex development',
#   '46,xx testicular dsd',
#   '46,xx gonadal dysgenesis',
#   'xx male syndrome',
#   '46, xx gonadal sex reversal',
#   'xx sex reversal'],
#  'GARD:0000400': ['gapo syndrome',
#   'growth retardation, alopecia, pseudoanodontia and optic atrophy'],
#  'GARD:0000404': ['osteoporosis oculocutaneous hypopigmentation syndrome',
#   'ooch syndrome'],
#  'GARD:0000405': ['subaortic stenosis short stature syndrome',
#   'onat syndrome'],
#  'GARD:0000406': ['o donnell pappas syndrome',
#   'foveal hypoplasia, presenile cataract',
#   'foveal hypoplasia, congenital nystagmus, corneal pannus, and presenile cataracts'],
#  'GARD:0000407': ['ermine phenotype',
#   'pigmentary disorder with hearing loss',
#   "o'doherty syndrome"],
#  'GARD:0000408': ['kowarski syndrome',
#   'biodefective growth hormone',
#   'pituitary dwarfism with normal immunoreactive growth hormone and low somatomedin'],
#  'GARD:0000409': ['pachygyria-intellectual disability-epilepsy syndrome',
#   'pachygyria, mental retardation and epilepsy (formerly)',
#   'kuzniecky syndrome'],
#  'GARD:0000411': ['hypoparathyroidism-intellectual disability-dysmorphism syndrome',
#   'sanjad-sakati syndrome',
#   'hrd syndrome',
#   'hypoparathyroidism with short stature, intellectual disability and seizures',
#   'hypoparathyroidism, congenital, associated with dysmorphism, growth retardation and developmental delay',
#   'hypoparathyroidism-short stature-intellectual disability-seizures syndrome',
#   'richardson-kirk syndrome'],
#  'GARD:0000413': ['geroderma osteodysplastica',
#   'walt disney dwarfism',
#   'gerodermia osteodysplastica',
#   'geroderma osteodysplasticum'],
#  'GARD:0000414': ['bamforth syndrome',
#   'hypothyroidism cleft palate hypothyroidism, athyroidal, with spiky hair and cleft palate',
#   'bamforth-lazarus syndrome'],
#  'GARD:0000415': ['pseudoprogeria syndrome',
#   'absent eyebrows and eyelashes with mental retardation',
#   'mental retardation, absence of eyebrows and eyelashes, progressive spastic quadriplegia, microcephaly, glaucoma, and small, beaked nose'],
#  'GARD:0000418': ['pentosuria',
#   'l-xylulosuria',
#   'xylitol dehydrogenase deficiency',
#   'l-xylulose reductase deficiency'],
#  'GARD:0000420': ['turcot syndrome',
#   'malignant tumors of the central nervous system associated with familial polyposis of the colon',
#   'cns tumors with familial polyposis of the colon',
#   'mismatch repair cancer syndrome',
#   'mismatch repair deficiency',
#   'mmr deficiency',
#   'brain tumor-polyposis syndrome',
#   'glioma-polyposis syndrome'],
#  'GARD:0000422': ['tunglang savage bellman syndrome',
#   'hearing loss insensitivity to aldosterone',
#   'hearing loss and familial salivary gland insensitivity to aldosterone'],
#  'GARD:0000424': ['xk aprosencephaly',
#   'garcia-lurie syndrome',
#   'aprosencephaly-atelencephaly syndrome',
#   'aprosencephaly syndrome',
#   'xk syndrome',
#   'xk-aprosencephaly syndrome'],
#  'GARD:0000425': ['tufted angioma', 'angioma tufted'],
#  'GARD:0000427': ['tucker syndrome',
#   'ptosis vocal cord paralysis',
#   'congenital bilateral recurrent nerve paralysis and ptosis'],
#  'GARD:0000429': ['amniotic band syndrome',
#   'amniotic bands sequence',
#   'familial amniotic bands',
#   'streeter anomaly',
#   'congenital constricting bands'],
#  'GARD:0000432': ['arbovirosis', 'arbovirus fever'],
# ...
#   'glycogen branching enzyme deficiency',
#   'cirrhosis, familial, with deposition of abnormal glycogen',
#   'glycogenosis 4',
#   'gsd iv'],
#  'GARD:0002523': ['gms syndrome',
#   'goniodysgenesis-intellectual disability-short stature syndrome'],
#  'GARD:0002533': ['gollop coates syndrome',
#   'bifurcation of distal humerus with oligoectro-syndactyly'],
#  'GARD:0002537': ['gombo syndrome',
#   'growth retardation, ocular abnormalities, microcephaly, brachydactyly, and oligophrenia'],
#  'GARD:0002542': ['perrault syndrome',
#   'gonadal dysgenesis, xx type, with deafness',
#   'ovarian dysgenesis with sensorineural deafness',
#   'gonadal dysgenesis, xx type'],
#  'GARD:0002551': ['goodpasture syndrome',
#   'rapidly progressive glomerulonephritis with pulmonary hemorrhage',
#   'anti-glomerular basement membrane antibody disease',
#   'glomerulonephritis - pulmonary hemorrhage',
#   'pulmonary renal syndrome'],
#  'GARD:0002553': ['gordon syndrome',
#   'arthrogryposis distal type 3',
#   'distal arthrogryposis type 3',
#   'camptodactyly, cleft palate, and clubfoot'],
#  'GARD:0002557': ['graham boyle troxell syndrome',
#   'cystic hamartoma of lung and kidney'],
#  'GARD:0002559': ['grant syndrome',
#   'persistent wormian bones, blue sclerae, mandibular hypoplasia, shallow glenoid fossae and campomelia'],
#  'GARD:0002562': ['gray platelet syndrome',
#   'platelet alpha-granule deficiency',
#   'marked decrease or absence of alpha-granules and of platelet-specific alpha-granule proteins'],
#  'GARD:0002566': ['griscelli syndrome type 1',
#   'griscelli syndrome with neurologic impairment',
#   'partial albinism and primary neurologic disease without hemophagocytic syndrome',
#   'pigmentary dilution of the skin and hair, the presence of large clumps of pigment in hair shafts',
#   'griscelli syndrome, cutaneous and neurologic type'],
#  'GARD:0002567': ['grix blankenship peterson syndrome',
#   'craniofacial and osseous defects mental retardation'],
#  'GARD:0002568': ['groll hirschowitz syndrome',
#   'nerve type deafness with mesenteric diverticula of small bowel and progressive sensory neuropathy'],
#  'GARD:0002572': ['myhre syndrome',
#   'facial dysmorphism - intellectual deficit - short stature - hearing loss',
#   'laryngotracheal stenosis, arthropathy, prognathism, and short stature',
#   'laps syndrome',
#   'growth mental deficiency syndrome of myhre'],
#  'GARD:0002574': ['growth retardation hydrocephaly lung hypoplasia',
#   'hydrocepalus with associated malformations',
#   'game-friedman-paradice syndrome'],
#  'GARD:0002576': ['grubben de cock borghgraef syndrome',
#   'severe growth retardation, developmental delay with hypotonia, hypotrophy of the distal extremities, dental anomalies, and eczematous skin',
#   'growth retardation, small and puffy hands and feet, and eczema',
#   'developmental delay - hypotonia - extremities hypertrophy'],
#  'GARD:0002578': ['guanidinoacetate methyltransferase deficiency',
#   'gamt deficiency',
#   'cerebral creatine deficiency syndrome 2'],
#  'GARD:0002579': ['osteopetrosis autosomal recessive 1',
#   'autosomal recessive osteopetrosis type 1',
#   'osteopetrosis infantile malignant 1',
#   'marble bones autosomal recessive'],
#  'GARD:0002582': ['hair defect-photosensitivity-intellectual disability syndrome',
#   'kinky hair, photosensitivity, broken eyebrows and eyelashes, and nonprogressive mental retardation (formerly)',
#   'calderon gonzalez-cantu syndrome',
#   'calderón-gonzález-cantu syndrome'],
#  'GARD:0002589': ['hamanishi ueba tsuji syndrome',
#   'congenital aplasia of the extensor muscles of the fingers and thumb associated with generalized polyneuropathy',
#   'polyneuropathy, hand defect'],
#  'GARD:0002593': ['hand and foot deformity with flat facies',
#   'familial syndrome of short stature, deformities of the hands and feet, and unusual facies',
#   'emery-nelson syndrome',
#   'hand and foot deformity - flat facies'],
#  'GARD:0002594': ['hand foot uterus syndrome',
#   'hfu syndrome',
#   'hfg syndrome',
#   'hand foot genital syndrome'],
#  'GARD:0002597': ['tendons, extensor, of fingers, anomalous insertion of',
#   'anomalous insertion of extensor tendons of fingers',
#   'hapnes boman skeie syndrome'],
#  'GARD:0002598': ['hard skin syndrome parana type',
#   'parana hard skin syndrome'],
#  'GARD:0002599': ['walker-warburg syndrome',
#   'hydrocephalus, agyria and retinal dysplasia',
#   'hard syndrome',
#   'hard +/- e syndrome',
#   'warburg syndrome',
#   'chemke syndrome',
#   'pagon syndrome',
#   'cerebroocular dysgenesis',
#   'cerebroocular dysplasia muscular dystrophy syndrome',
#   'cod-md syndrome'],
#  'GARD:0002600': ['harding ataxia',
#   'cerebellar ataxia early onset with retained tendon reflex',
#   'ataxia, harding type'],
#  'GARD:0002601': ['harrod doman keele syndrome',
#   'harrod syndrome',
#   'craniofacial digital genital anomalies'],
#  'GARD:0002604': ['hashimoto-pritzker syndrome',
#   'hashimoto-pritzker histiocytosis',
#   'hashimoto-pritzker disease',
#   'congenital langerhans cell histiocytosis',
#   'obsolete: hashimoto-pritzker syndrome'],
#  'GARD:0002605': ['short stature-craniofacial anomalies-genital hypoplasia syndrome',
#   'haspeslagh syndrome',
#   'pterygia mental retardation facial dysmorphism',
#   'haspeslagh-fryns-muelenaere syndrome'],
#  'GARD:0002610': ['progressive familial heart block type 1b',
#   'heart block progressive familial type 1b',
#   'pfhb1b'],
#  'GARD:0002613': ['cardioskeletal syndrome kuwaiti type',
#   'heart defects and limb shortening'],
#  'GARD:0002614': ['heart-hand syndrome, spanish type',
#   'brachydactyly and intraventricular conduction defect',
#   'upper limb malformations and congenital cardiac anomalies'],
#  'GARD:0002619': ['heart tumor',
#   'myocardial tumors (rhabdomyomas and fibromas)',
#   'intracavitary tumors',
#   'primary cardiac tumors, childhood'],
#  'GARD:0002620': ['hec syndrome',
#   'hydrocephalus, endocardial fibroelastosis, and cataracts',
#   'communicating hydrocephalus, endocardial fibroelastosis (efe) and congenital cataracts'],
#  'GARD:0002621': ['trismus-pseudocamptodactyly syndrome',
#   'hecht syndrome',
#   'dutch-kentucky syndrome',
#   'distal arthrogryposis type 7',
#   'arthrogryposis distal type 7'],
#  'GARD:0002622': ['fibular aplasia, tibial campomelia, and oligosyndactyly syndrome',
#   'fatco syndrome',
#   'terminal transverse defects of the limbs associated with congenital heart malformations',
#   'hecht-scott syndrome',
#   'limb deficiency-heart malformation syndrome',
#   'fibular aplasia-tibial campomelia-oligosyndactyly syndrome'],
#  'GARD:0002633': ['hemifacial hyperplasia strabismus', 'bencze syndrome'],
#  'GARD:0002637': ['hemimegalencephaly',
#   'macrencephaly',
#   'unilateral megalencephaly'],
#  'GARD:0002640': ['hemoglobin c disease', 'hb c disease'],
#  'GARD:0002658': ['tyrosinemia type 1',
#   'tyrosinemia type i',
#   'hepatorenal tyrosinemia',
#   'fumarylacetoacetase deficiency',
#   'fah deficiency'],
#  'GARD:0002659': ['hereditary methemoglobinemia',
#   'congenital methemoglobinemia'],
#  'GARD:0002669': ['herpes virus antenatal infection',
#   'congenital hsv infection'],
#  'GARD:0002672': ['hersh podruch weisskopk syndrome',
#   'toluene embryopathy',
#   'microcephaly, central nervous system dysfunction, minor craniofacial and limb anomalies, and variable growth deficiency'],
#  'GARD:0002684': ['high molecular weight kininogen deficiency',
#   'high-molecular-weight kininogen deficiency, congenital',
#   'flaujeac factor deficiency'],
#  'GARD:0002690': ['beukes familial hip dysplasia',
#   'hip dysplasia beukes type',
#   'osteoarthropathy, premature degenerative, of hip',
#   'cilliers-beighton syndrome'],
#  'GARD:0002695': ['hirschsprung disease ganglioneuroblastoma',
#   'neuroblastoma with hirschsprung disease'],
#  'GARD:0002699': ['hirschsprung disease type 3',
#   'hirschsprung disease modifier'],
#  'GARD:0002700': ['hirschsprung disease type d brachydactyly',
#   "familial hirschsprung's disease and type d brachydactyly"],
#  'GARD:0002708': ['histidinuria renal tubular defect', 'renal histidinuria'],
#  'GARD:0002714': ['hodgkin lymphoma',
#   'hodgkin disease',
#   "hodgkin's lymphoma",
#   "lymphoma, hodgkin's"],
#  'GARD:0002721': ['holocarboxylase synthetase deficiency',
#   'early-onset multiple carboxylase deficiency',
#   'neonatal multiple carboxylase deficiency'],
#  'GARD:0002725': ['holoprosencephaly ectrodactyly cleft lip palate',
#   'hartsfield syndrome'],
#  'GARD:0002727': ['steinfeld syndrome',
#   'holoprosencephaly radial heart renal anomalies'],
#  'GARD:0002728': ['holzgreve syndrome',
#   'complex congenital heart defect, renal agenesis and cleft lip and palate'],
#  'GARD:0002730': ['homocarnosinosis', 'homocarnosinase deficiency'],
#  'GARD:0002734': ['homocystinuria due to mthfr deficiency',
#   'homocysteinemia due to methylenetetrahydro-folate reductase deficiency',
#   'methylenetetrahydro-folate reductase deficiency',
#   'homocysteinuria due to methylenetetrahydro-folate reductase deficiency',
#   '5,10-alpha-methylenetetrahydro-folate reductase deficiency',
#   '5,10 alpha methylenetetrahydro-folate reductase deficiency'],
#  'GARD:0002736': ['hordnes engebretsen knudtson syndrome',
#   'acrobrachycephaly, ventriculomegaly, pulmonary stenosis, ectopic anus and mental retardation'],
#  'GARD:0002748': ['humeroradial synostosis',
#   'humero-radial synostosis',
#   'humero-radial fusion'],
#  'GARD:0002750': ['trochlea of the humerus aplasia of',
#   'aplasia of trochlea of the humerus'],
#  'GARD:0002754': ['hunter-mcalpine syndrome',
#   'hunter-mcalpine craniosynostosis syndrome',
#   'hunter-mcalpine craniosynostosis',
#   'craniosynostosis, mental deficiency, almond-shaped palpebral fissures, downturned mouth, mild acral-skeletal anomalies, and short stature'],
#  'GARD:0002765': ['x-linked intellectual disability-plagiocephaly syndrome',
#   'mental retardation, x-linked, with craniofacial dysmorphism',
#   'mental retardation, x-linked, hyde-forster type',
#   'hyde forster mccarthy berry syndrome'],
#  'GARD:0002775': ['hydrocephalus obesity hypogonadism',
#   'congenital hydrocephalus oligophrenia dwarfism centripetal obesity and hypogonadism'],
#  'GARD:0002783': ['hydrops fetalis',
#   'idiopathic hydrops fetalis',
#   'hydrops fetalis nonimmune',
#   'familial non-immune hydrops fetalis'],
#  'GARD:0002786': ['hygroma cervical',
#   'cystic hygroma of the neck (posterior)',
#   'hygroma cervicis',
#   'jugular lymphatic obstruction sequence',
#   'nuchal lymphangioma'],
#  'GARD:0002787': ['hymenolepiasis', 'hymenolepsis infection'],
#  'GARD:0002788': ['hyper-igd syndrome',
#   'hyper igd syndrome',
#   'hyperimmunoglobulinemia d and periodic fever syndrome',
#   'periodic fever dutch type'],
#  'GARD:0002789': ['familial hyperaldosteronism type 2',
#   'familial hyperaldosteronism type ii',
#   'familial adrenal adenoma'],
#  'GARD:0002790': ['glucocorticoid-remediable aldosteronism',
#   'familial hyperaldosteronism type 1',
#   'hyperaldosteronism, familial  type 1',
#   'dexamethasone sensitive hypertension',
#   'glucocorticoid sensitive hypertension'],
#  'GARD:0002796': ['familial hypocalciuric hypercalcemia type 1',
#   'hypocalciuric hypercalcemia, familial, type 1',
#   'hypercalcemia, familial benign type 1',
#   'familial benign hypercalcemia type 1',
#   'fhh type 1'],
#  'GARD:0002804': ['hypereosinophilic syndrome',
#   'hypereosinophilic syndrome, idiopathic'],
#  'GARD:0002806': ['hyperferritinemia cataract syndrome',
#   'hereditary hyperferritinemia cataract syndrome',
#   'cataract-hyperferritinemia syndrome',
#   'bonneau-beaumont syndrome'],
#  'GARD:0002807': ['hyperglycerolemia',
#   'glycerol kinase deficiency',
#   'gk deficiency',
#   'gk1 deficiency'],
#  'GARD:0002816': ['autosomal recessive hyper ige syndrome',
#   'dock8 deficiency',
#   'hyperimmunoglobulin e recurrent infection syndrome, autosomal recessive',
#   'hies autosomal recessive',
#   'ar-hies',
#   'ar hyperimmunoglobulin e syndrome',
#   'hyper ig e syndrome, autosomal recessive'],
#  'GARD:0002824': ['hyperkeratosis lenticularis perstans',
#   'flegel disease',
#   "flegel's disease",
#   'hyperkeratosis lenticularis perstans of flegel'],
#  'GARD:0002826': ['epidermolytic palmoplantar keratoderma',
#   'hyperkeratosis palmoplantar localized epidermolytic',
#   'diffuse erythrodermic palmoplantar keratoderma, vörner type',
#   'epidermolytic palmoplantar keratoderma of voerner',
#   'epidermolytic palmoplantar keratoderma of vörner',
#   'tylosis',
#   'keratosis of greither'],
#  'GARD:0002828': ['hyperlysinemia',
#   'lysine alpha-ketoglutarate reductase deficiency',
#   'alpha-aminoadipic semialdehyde synthase deficiency',
#   'l-lysine nad-oxido-reductase deficiency',
#   'lysine intolerance'],
#  'GARD:0002830': ['ornithine translocase deficiency syndrome',
#   'hyperornithinemia-hyperammonemia-homocitrullinuria syndrome',
#   'hhh syndrome',
#   'ornithine translocase deficiency'],
#  'GARD:0002831': ['juvenile paget disease',
#   'hyperostosis corticalis deformans juvenilis',
#   'hyperphosphatasia, familial idiopathic',
#   'hyperphosphatasemia, chronic congenital idiopathic',
#   'paget disease juvenile type',
#   'paget disease of bone 5, juvenile-onset',
#   'hereditary hyperphosphatasia',
#   'hyperostosid corticalis deformans juvenilis',
#   'juvenile pagets disease'],
#  'GARD:0002833': ['hyperostosis corticalis generalisata',
#   'van buchem disease',
#   'hyperphosphatasemia tarda',
#   'endosteal hyperostosis autosomal recessive'],
#  'GARD:0002835': ['primary hyperoxaluria type 1',
#   'oxalosis 1',
#   'glycolic aciduria',
#   'alanine-glyoxylate aminotransferase deficiency',
#   'peroxisomal alanine glyoxylate aminotransferase deficiency',
#   'hepatic agt deficiency',
#   'serine pyruvate aminotransferase deficiency'],
#  'GARD:0002836': ['primary hyperoxaluria type 2',
#   'oxalosis 2',
#   'glyoxylate reductase/hydroxypyruvate reductase deficiency',
#   'glyceric aciduria',
#   'd-glycerate dehydrogenase deficiency'],
#  'GARD:0002837': ['familial isolated hyperparathyroidism',
#   'hyperparathyroidism 1',
#   'hyperparathyroidism, familial isolated primary',
#   'familial primary hyperparathyroidism'],
#  'GARD:0002843': ['hyperphenylalaninemia due to dehydratase deficiency',
#   'dehydratase deficiency',
#   'hyperphenylalaninemia with primapterinuria',
#   'hyperphenylalaninemia, bh4-deficient, d',
#   'hyperphenylalaninemia, tetrahydrobiopterin-deficient, due to pterin-4-alpha-carbinolamine dehydratase deficiency',
#   'hyperphenylalaninemia due to pterin-4-alpha-carbinolamine dehydratase deficiency',
#   'tetrahydrobiopterin (bh4)-deficient hyperphenylalaninemia (hpa) due to pterin-4-alpha-carbinolamine dehydratase deficiency',
#   'cadh deficiency',
#   'pcbd deficiency',
#   'pterin-4 alpha-carbinolamine dehydratase deficiency'],
#  'GARD:0002844': ['gtp cyclohydrolase i deficiency',
#   'hyperphenylalaninemia, tetrahydrobiopterin-deficient, due to gtp cyclohydrolase 1 deficiency',
#   'hyperphenylalaninemia, bh4-deficient, b'],
#  'GARD:0002847': ['hyperprolinemia',
#   'proline oxidase deficiency',
#   'proline hydrogenase deficiency',
#   'hyperprolinemia type 1'],
#  'GARD:0002858': ['familial hyperthyroidism due to mutations in tsh receptor',
#   'familial non-immune hyperthyroidism',
#   'nonautoimmune hyperthyroidism',
#   'resistance to thyroid stimulating hormone'],
#  'GARD:0002863': ['x-linked congenital generalized hypertrichosis',
#   'macias-flores garcia-cruz rivera syndrome',
#   'chromosome  xq27.1 interchromosomal insertion syndrome',
#   'hypertrichosis congenital generalized x-linked',
#   'congenital generalized hypertrichosis, macias-flores type',
#   'macias flores-garcia cruz-rivera syndrome'],
#  'GARD:0002865': ['congenital hypertrichosis lanuginosa',
#   'hypertrichosis lanuginosa universalis'],
#  'GARD:0002872': ['familial hdl deficiency',
#   'hypoalphalipoproteinemia, familial',
#   'high density lipoprotein deficiency',
#   'hypoalphalipoproteinemia, primary'],
#  'GARD:0002876': ['familial hypobetalipoproteinemia',
#   'hypobetalipoproteinemia, familial'],
#  'GARD:0002878': ['familial hypocalciuric hypercalcemia type 3',
#   'familial benign hypercalcemia, type 3',
#   'hypercalcemia, familial benign, type 3',
#   'hypercalcemia, familial benign, oklahoma type',
#   'familial benign hypercalcemia, oklahoma variant',
#   'hypocalciuric hypercalcemia, familial, type 3'],
#  ...}

# %%
rand_id = random.choice(list(multiple_names.keys()))
rand_id
# Out:
# 'GARD:0009669'

# %%
single_names
# Out:
# {'GARD:0000091': ['malignant melanoma, childhood'],
#  'GARD:0000101': ['centronuclear myopathy'],
#  'GARD:0000161': ['saul wilkes stevenson syndrome'],
#  'GARD:0000166': ['schizencephaly'],
#  'GARD:0000183': ['bubonic plague'],
#  'GARD:0000203': ["crohn's disease of the esophagus"],
#  'GARD:0000206': ['nephronophthisis'],
#  'GARD:0000219': ['congenital giant megaureter'],
#  'GARD:0000225': ['radial ray agenesis'],
#  'GARD:0000273': ['wrinkly skin syndrome'],
#  'GARD:0000303': ['jeune syndrome situs inversus'],
#  'GARD:0000317': ['sacral hemangiomas multiple congenital abnormalities'],
#  'GARD:0000319': ['sacrococcygeal teratoma'],
#  'GARD:0000412': ['cheilitis glandularis'],
#  'GARD:0000431': ['microtia-anotia'],
#  'GARD:0000456': ['achalasia microcephaly syndrome'],
#  'GARD:0000478': ['acral dysostosis dyserythropoiesis syndrome'],
#  'GARD:0000495': ['acrofacial dysostosis preis type'],
#  'GARD:0000506': ['acromesomelic dysplasia hunter thompson type'],
#  'GARD:0000519': ['idiopathic acute eosinophilic pneumonia'],
#  'GARD:0000523': ['acute lymphoblastic leukemia congenital sporadic aniridia'],
#  'GARD:0000537': ['acute non lymphoblastic leukemia'],
#  'GARD:0000558': ['adrenocortical carcinoma'],
#  'GARD:0000562': ['adrenomyodystrophy'],
#  'GARD:0000572': ['agyria pachygyria polymicrogyria'],
#  'GARD:0000573': ['agyria-pachygyria type 1'],
#  'GARD:0000581': ['asrar facharzt haque syndrome'],
#  'GARD:0000596': ['albright like syndrome'],
#  'GARD:0000632': [],
#  'GARD:0000637': ['amaurosis congenita cone-rod type with congenital hypertrichosis'],
#  'GARD:0000683': ['angiostrongyliasis'],
#  'GARD:0000697': ['ankyloblepharon filiforme imperforate anus'],
#  'GARD:0000704': ['annular constricting bands'],
#  'GARD:0000708': ['anonychia ectrodactyly'],
#  'GARD:0000715': ['anophthalmia cleft palate micrognathia'],
#  'GARD:0000716': ['anophthalmia esophageal atresia cryptorchidism'],
#  'GARD:0000717': ['anophthalmia megalocornea cardiopathy skeletal anomalies'],
#  'GARD:0000725': ['anotia facial palsy cardiac defect'],
#  'GARD:0000730': ['anti-hla hyperimmunization'],
#  'GARD:0000740': ['aortic arch interruption'],
#  'GARD:0000742': ['aortic dissection lentiginosis'],
#  'GARD:0000744': ['aortic valves stenosis of the child'],
#  'GARD:0000748': ['aphalangia partial with syndactyly and duplication of metatarsal iv'],
#  'GARD:0000756': ['aplasia cutis myopia'],
#  'GARD:0000758': ['apo a-i deficiency'],
#  'GARD:0000763': ['amino aciduria with mental deficiency, dwarfism, muscular dystrophy, osteoporosis and acidosis'],
#  'GARD:0000779': ['arthrogryposis due to muscular dystrophy'],
#  'GARD:0000785': ['arthrogryposis multiplex congenita cns calcification'],
#  'GARD:0000795': ['arthrogryposis spinal muscular atrophy'],
#  'GARD:0000802': ['atrioventricular septal defect'],
#  'GARD:0000820': ['bardet-biedl syndrome 1'],
#  'GARD:0000821': ['bardet-biedl syndrome 2'],
#  'GARD:0000822': ['bardet-biedl syndrome 3'],
#  'GARD:0000823': ['bardet-biedl syndrome 4'],
#  'GARD:0000826': ['frontometaphyseal dysplasia'],
#  'GARD:0000835': ['benign muscular dystrophy with hypergonadotrophic hypogonadism and congenital cataract'],
#  'GARD:0000841': [],
#  'GARD:0000855': ['benign autosomal dominant myopathy'],
#  'GARD:0000857': ['benign familial infantile epilepsy'],
#  'GARD:0000870': ['beta-sarcoglycanopathy'],
#  'GARD:0000881': ['biemond syndrome type 1'],
#  'GARD:0000885': ['bilateral renal agenesis dominant type'],
#  'GARD:0000887': ['biliary atresia intrahepatic non syndromic form'],
#  'GARD:0000888': ['biliary atresia intrahepatic syndromic form'],
#  'GARD:0000902': ['blepharo naso facial syndrome van maldergem type'],
#  'GARD:0000920': ['bone dysplasia azouz type'],
#  'GARD:0000921': ['bone dysplasia corpus callosum agenesis'],
#  'GARD:0000922': ['bone dysplasia lethal holmgren type'],
#  'GARD:0000923': ['bone dysplasia moore type'],
#  'GARD:0000942': ['bothriocephalosis'],
#  'GARD:0000953': ['bowing of long bones congenital'],
#  'GARD:0000961': ['brachydactyly absence of distal phalanges'],
#  'GARD:0000962': ['brachydactyly anonychia'],
#  'GARD:0000974': ['brachydactyly small stature face anomalies'],
#  'GARD:0000977': ['brachydactyly tibial hypoplasia'],
#  'GARD:0000985': ['brachydactyly type b'],
#  'GARD:0000989': ['brachymesophalangy type 2'],
#  'GARD:0000992': ['brachymetapody anodontia hypotrichosis albinoidism'],
#  'GARD:0000998': ['braddock jones superneau syndrome'],
#  'GARD:0001001': ['branchial arch defects'],
#  'GARD:0001018': ['brittle bone syndrome lethal type'],
#  'GARD:0001023': ['bronchiectasis oligospermia'],
#  'GARD:0001025': ['bronchogenic cyst'],
#  'GARD:0001026': ['amyloidosis bronchopulmonary'],
#  'GARD:0001034': ['bruyn scheltens syndrome'],
#  'GARD:0001041': ['burn goodship syndrome'],
#  'GARD:0001064': ['camptodactyly, fibrous tissue hyperplasia, and skeletal dysplasia'],
#  'GARD:0001082': ['cantu sanchez-corona garcia-cruz syndrome'],
#  'GARD:0001094': ['cardiac diverticulum'],
#  'GARD:0001097': ['cardiofacial syndrome short limbs'],
#  'GARD:0001099': ['cardiomelic syndrome stratton koehler type'],
#  'GARD:0001103': ['cardiomyopathy diabetes deafness'],
#  'GARD:0001104': ['cardiomyopathy dilated with conduction defect type 1'],
#  'GARD:0001107': ['cardiomyopathy due to anthracyclines'],
#  'GARD:0001109': ['cardiomyopathy hypogonadism metabolic anomalies'],
#  'GARD:0001110': ['cardiomyopathy spherocytosis'],
#  'GARD:0001113': ['fatal infantile encephalomyopathy'],
#  'GARD:0001123': ['carnitine-acylcarnitine translocase deficiency'],
#  'GARD:0001129': ['carpo tarsal osteolysis recessive'],
#  'GARD:0001143': ['cataract congenital autosomal dominant'],
#  'GARD:0001146': ['cataract congenital volkmann type'],
#  'GARD:0001150': ['cataract hutterite type'],
#  'GARD:0001158': ['cataract skeletal anomalies'],
#  'GARD:0001160': ['cataract-glaucoma'],
#  'GARD:0001164': ['caudal duplication'],
#  'GARD:0001174': ['cdg syndrome type 4'],
#  'GARD:0001175': ['cdk4 linked melanoma'],
#  'GARD:0001187': ['cerebellar agenesis'],
#  'GARD:0001194': ['cerebellar hypoplasia'],
#  'GARD:0001195': ['cerebellar hypoplasia with endosteal sclerosis'],
#  'GARD:0001196': ['cerebellar hypoplasia tapetoretinal degeneration'],
#  'GARD:0001201': ['cerebral calcification cerebellar hypoplasia'],
#  'GARD:0001202': ['cerebral calcifications opalescent teeth phosphaturia'],
#  'GARD:0001235': ['chaotic atrial tachycardia'],
#  'GARD:0001261': ['charlie m syndrome'],
#  'GARD:0001265': ['abdominal chemodectomas with cutaneous angiolipomas'],
#  'GARD:0001294': ['lethal recessive chondrodysplasia'],
#  'GARD:0001298': ['chondrodysplasia punctata sheffield type'],
#  'GARD:0001302': ['chondrodysplasia punctata, humero-metacarpal type'],
#  'GARD:0001303': ['chordoma'],
#  'GARD:0001306': ['choreoacanthocytosis amyotrophic'],
#  'GARD:0001309': ['choroid plexus cyst'],
#  'GARD:0001312': ['choroideremia hypopituitarism'],
#  'GARD:0001315': ['christian demyer franken syndrome'],
#  'GARD:0001316': ['christian johnson angenieta syndrome'],
#  'GARD:0001352': ['chronic demyelinizing neuropathy with igm monoclonal'],
#  'GARD:0001355': ['chronic polyradiculoneuritis'],
#  'GARD:0001360': ['ciliary discoordination, due to random ciliary orientation'],
#  'GARD:0001361': ['ciliary dyskinesia, due to transposition of ciliary microtubules'],
#  'GARD:0001362': ['ciliary dyskinesia-bronchiectasis'],
#  'GARD:0001365': ['circumscribed cutaneous aplasia of the vertex'],
#  'GARD:0001366': ['circumscribed disseminated keratosis jadassohn lew type'],
#  'GARD:0001371': ['cleft lip and palate malrotation cardiopathy'],
#  'GARD:0001375': ['cleft lip palate dysmorphism kumar type'],
#  'GARD:0001381': ['cleft lip palate oligodontia syndactyly pili torti'],
#  'GARD:0001382': ['cleft lip palate pituitary deficiency'],
#  'GARD:0001383': ['cleft lip palate-tetraphocomelia'],
#  'GARD:0001386': ['cleft lower lip cleft lateral canthi chorioretinal'],
#  'GARD:0001388': ['cleft palate colobomata radial synostosis deafness'],
#  'GARD:0001389': ['cleft palate heart disease polydactyly absent tibia'],
#  'GARD:0001391': ['cleft palate lateral synechia syndrome'],
#  'GARD:0001393': ['cleft palate stapes fixation oligodontia'],
#  'GARD:0001419': ['coenzyme q cytochrome c reductase deficiency of'],
#  'GARD:0001423': ['cohen lockood wyborney syndrome'],
#  'GARD:0001429': ['collins sakati syndrome'],
#  'GARD:0001433': ['coloboma of eye lens'],
#  'GARD:0001434': ['coloboma of iris'],
#  'GARD:0001438': ['coloboma of optic papilla'],
#  'GARD:0001439': ['coloboma porencephaly hydronephrosis'],
#  'GARD:0001442': ['colobomata unilobar lung heart defect'],
#  'GARD:0001446': ['colonic atresia'],
#  'GARD:0001448': ['colver steer godman syndrome'],
#  'GARD:0001449': ['combarros calleja leno syndrome'],
#  'GARD:0001452': ['complement component 2 deficiency'],
#  'GARD:0001453': ['complement component receptor 1'],
#  'GARD:0001467': ['congenital adrenal hyperplasia'],
#  'GARD:0001471': ['congenital amputation'],
#  'GARD:0001472': ['congenital aneurysms of the great vessels'],
#  'GARD:0001473': ['congenital articular rigidity'],
#  'GARD:0001474': ['congenital benign spinal muscular atrophy dominant'],
#  'GARD:0001475': ['congenital bronchobiliary fistula'],
#  'GARD:0001477': ['congenital contractures'],
#  'GARD:0001478': ['congenital craniosynostosis maternal hyperthyroiditis'],
#  'GARD:0001479': ['congenital cystic eye multiple ocular and intracranial anomalies'],
#  'GARD:0001483': ['congenital heart disease ptosis hypodontia craniostosis'],
#  'GARD:0001484': ['congenital heart disease radio ulnar synostosis mental retardation'],
#  'GARD:0001488': ['congenital hypotrichosis milia'],
#  'GARD:0001492': ['congenital megalo-ureter'],
#  'GARD:0001493': ['congenital mesoblastic nephroma'],
#  'GARD:0001495': ['congenital mitral malformation'],
#  'GARD:0001496': ['congenital mitral stenosis'],
#  'GARD:0001497': ['congenital myxovirus'],
#  'GARD:0001498': ['congenital mumps'],
#  'GARD:0001502': ['short bowel syndrome'],
#  'GARD:0001504': ['congenital stenosis of cervical medullary canal'],
#  'GARD:0001507': ['congenital unilateral pulmonary hypoplasia'],
#  'GARD:0001508': ['congenital vagal hyperreflexivity'],
#  'GARD:0001512': ['hereditary continuous muscle fiber activity'],
#  'GARD:0001523': ['cormier rustin munnich syndrome'],
#  'GARD:0001526': ['corneal crystals myopathy neuropathy'],
#  'GARD:0001528': ['corneal dystrophy ichthyosis microcephaly mental retardation'],
#  'GARD:0001530': ['corneal dystrophy pigmentary anomaly malabsorption'],
#  'GARD:0001533': ['coronaro-cardiac fistula'],
#  'GARD:0001534': ['coronary arteries congenital malformation'],
#  'GARD:0001538': ['corpus callosum agenesis of blepharophimosis robin type'],
#  'GARD:0001541': ['corpus callosum dysgenesis cleft spasm'],
#  'GARD:0001542': ['corpus callosum dysgenesis hypopituitarism'],
#  'GARD:0001543': ['corpus callosum dysgenesis x-linked recessive'],
#  'GARD:0001546': ['cortada koussef matsumoto syndrome'],
#  'GARD:0001547': ['cortes lacassie syndrome'],
#  'GARD:0001548': ['cortical blindness-intellectual disability-polydactyly syndrome'],
#  'GARD:0001558': ['coxoauricular syndrome'],
#  'GARD:0001564': ['cranio osteoarthropathy'],
#  'GARD:0001567': ['craniodiaphyseal dysplasia'],
#  'GARD:0001570': ['craniofacial and skeletal defects'],
#  'GARD:0001579': ['craniofrontonasal syndrome teebi type'],
#  'GARD:0001582': ['craniometaphyseal dysplasia, autosomal recessive type'],
#  'GARD:0001583': ['craniomicromelic syndrome'],
#  'GARD:0001584': ['craniostenosis cataract'],
#  'GARD:0001586': ['craniosynostosis alopecia brain defect'],
#  'GARD:0001587': ['craniosynostosis arthrogryposis cleft palate'],
#  'GARD:0001588': ['craniosynostosis autosomal dominant'],
#  'GARD:0001590': ['craniosynostosis cleft lip palate arthrogryposis'],
#  'GARD:0001591': ['craniosynostosis contractures cleft'],
#  'GARD:0001593': ['craniosynostosis exostoses nevus epibulbar dermoid'],
#  'GARD:0001595': ['craniosynostosis fontaine type'],
#  'GARD:0001598': ['craniosynostosis maroteaux fonfria type'],
#  'GARD:0001601': ['craniosynostosis philadelphia type'],
#  'GARD:0001607': ['crawfurd syndrome'],
#  'GARD:0001609': ['creeping myiasis'],
#  'GARD:0001610': ['cretinism athyreotic'],
#  'GARD:0001616': ['crossed polydactyly type 1'],
#  'GARD:0001617': ['crossed polysyndactyly'],
#  'GARD:0001635': ['cutis gyratum acanthosis nigricans craniosynostosis'],
#  'GARD:0001637': ['cutis laxa osteoporosis'],
#  'GARD:0001643': ['cutis verticis gyrata'],
#  'GARD:0001644': ['cutis verticis gyrata mental deficiency'],
#  'GARD:0001646': ['cutler bass romshe syndrome'],
#  'GARD:0001658': ['cytoplasmic body myopathy'],
#  'GARD:0001684': ['deafness conductive stapedial ear malformation facial palsy'],
#  'GARD:0001686': ['deafness craniofacial syndrome'],
#  'GARD:0001689': ['deafness goiter stippled epiphyses'],
#  'GARD:0001691': ['deafness hypogonadism syndrome'],
#  'GARD:0001692': ['deafness hypospadias metacarpal and metatarsal syndrome'],
#  'GARD:0001693': ['deafness mesenteric diverticula of small bowel neuropathy'],
#  'GARD:0001694': ['deafness mixed with perilymphatic gusher, x-linked'],
#  'GARD:0001701': ['deafness peripheral neuropathy arterial disease'],
#  'GARD:0001702': ['deafness progressive cataract autosomal dominant'],
#  'GARD:0001707': ['deafness x-linked, dfn3'],
#  'GARD:0001709': ['deafness, isolated, due to mitochondrial transmission'],
#  'GARD:0001710': ['deafness, neurosensory nonsyndromic recessive, dfn'],
#  'GARD:0001715': ['deafness, x-linked, dfn'],
#  'GARD:0001720': ['defective apolipoprotein b-100'],
#  'GARD:0001798': ['delta-1-pyrroline-5-carboxylate dehydrogenase deficiency'],
#  'GARD:0001799': ['delta-sarcoglycanopathy'],
#  'GARD:0001802': ['demodicidosis'],
#  'GARD:0001812': ['dermatocardioskeletal syndrome boronne type'],
#  'GARD:0001813': ['dermatoleukodystrophy'],
#  'GARD:0001827': ['dextrocardia'],
#  'GARD:0001840': ['diabetes persistent mullerian ducts'],
#  'GARD:0001843': ['diaphragmatic agenesis radial aplasia omphalocele'],
#  'GARD:0001846': ['diaphragmatic hernia exomphalos corpus callosum agenesis'],
#  'GARD:0001847': ['diaphragmatic hernia upper limb defects'],
#  'GARD:0001853': ['dibasic aminoaciduria 2'],
#  'GARD:0001854': ['dibasic aminoaciduria 1'],
#  'GARD:0001857': ['die smulders droog van dijk syndrome'],
#  'GARD:0001858': ['die smulders vles fryns syndrome'],
#  'GARD:0001861': ['diffuse neonatal hemangiomatosis'],
#  'GARD:0001863': ['gastric duplication cysts'],
#  'GARD:0001870': ['diomedi bernardi placidi syndrome'],
#  'GARD:0001873': ['diphallus rachischisis imperforate anus'],
#  'GARD:0001874': ['diphosphoglycerate mutase deficiency of erythrocyte'],
#  'GARD:0001875': ['diphtheria'],
#  'GARD:0001876': ['diprosopia'],
#  'GARD:0001883': ['dissecting cellulitis of the scalp'],
#  'GARD:0001889': ['distal primary acidosis, familial'],
#  'GARD:0001890': ['distichiasis heart congenital anomalies'],
#  'GARD:0001891': ['distomatosis'],
#  'GARD:0001895': ['dobrow syndrome'],
#  'GARD:0001896': ['dominant cleft palate'],
#  'GARD:0001898': ['early-onset zonular cataract'],
#  'GARD:0001906': ['double fingernail of fifth finger'],
#  'GARD:0001907': ['double outlet left ventricle'],
#  'GARD:0001908': ['double outlet right ventricle'],
#  'GARD:0001919': ['duodenal atresia tetralogy of fallot'],
#  'GARD:0001976': ['duplication of leg mirror foot'],
#  'GARD:0001977': ['duplication of the thumb unilateral biphalangeal'],
#  'GARD:0001983': ['dupont sellier chochillon syndrome'],
#  'GARD:0001984': ['dwarfism bluish sclerae'],
#  'GARD:0001985': ['dwarfism deafness retinitis pigmentosa'],
#  'GARD:0001986': ['dwarfism lethal type advanced bone age'],
#  'GARD:0001992': ['dwarfism thin bones multiple fractures'],
#  'GARD:0001996': ['dyschromatosis universalis hereditaria'],
#  'GARD:0002003': ['dysferlinopathy'],
#  'GARD:0002009': ['dysmorphism cleft palate loose skin'],
#  'GARD:0002012': ['dysosteosclerosis'],
#  'GARD:0002022': ['dysplastic cortical hyperostosis'],
#  'GARD:0002025': ['dyssegmental dysplasia and glaucoma'],
#  'GARD:0002031': ['dystrophinopathy'],
#  'GARD:0002035': ['ebola virus disease'],
#  'GARD:0002042': ['ectodermal dysplasia arthrogryposis diabetes mellitus'],
#  'GARD:0002043': ['ectodermal dysplasia bartalos type'],
#  'GARD:0002044': ['ectodermal dysplasia berlin type'],
#  'GARD:0002045': ['ectodermal dysplasia blindness'],
#  'GARD:0002050': ['ectodermal dysplasia margarita type'],
#  'GARD:0002051': ['ectodermal dysplasia intellectual disability cns malformation'],
#  'GARD:0002053': ['ectodermal dysplasia neurosensory deafness'],
#  'GARD:0002055': ['ectodermal dysplasia trichoodontoonychial type'],
#  'GARD:0002068': ['ectrodactyly polydactyly'],
#  'GARD:0002074': ['edinburgh malformation syndrome'],
#  'GARD:0002099': ['emerinopathy'],
#  'GARD:0002106': ['enamel hypoplasia cataract hydrocephaly'],
#  'GARD:0002109': ['encephalocele anencephaly'],
#  'GARD:0002124': ['engelhard yatziv syndrome'],
#  'GARD:0002130': ['enterovirus antenatal infection'],
#  'GARD:0002136': ['epidermal nevus vitamin d resistant rickets'],
#  'GARD:0002143': ['junctional epidermolysis bullosa inversa'],
#  'GARD:0002163': ['epilepsy mental deterioration finnish type'],
#  'GARD:0002173': ['epilepsy, partial, familial'],
#  'GARD:0002175': ['epimetaphyseal dysplasia cataract'],
#  'GARD:0002177': ['epiphyseal dysplasia dysmorphism camptodactyly'],
#  'GARD:0002188': ['erosive pustular dermatosis of the scalp'],
#  'GARD:0002191': ['complement component 5 deficiency'],
#  'GARD:0002196': ['esophageal atresia coloboma talipes'],
#  'GARD:0002199': ['exencephaly'],
#  'GARD:0002204': ['exostoses, multiple, type 1'],
#  'GARD:0002205': ['exostoses, multiple, type 2'],
#  'GARD:0002206': ['exostoses, multiple, type 3'],
#  'GARD:0002216': ['eyebrows duplication of, with stretchable skin and syndactyly'],
#  'GARD:0002220': ['facial clefting corpus callosum agenesis'],
#  'GARD:0002226': ['facio digito genital syndrome recessive form'],
#  'GARD:0002229': ['faciocardiomelic dysplasia lethal'],
#  'GARD:0002237': ['factor v deficiency'],
#  'GARD:0002250': ['familial band heterotopia'],
#  'GARD:0002254': ['familial nasal acilia'],
#  'GARD:0002263': ['familial ventricular tachycardia'],
#  'GARD:0002280': ['feigenbaum bergeron syndrome'],
#  'GARD:0002287': ['fenton wilkinson toselano syndrome'],
#  'GARD:0002295': ['fetal and neonatal alloimmune thrombocytopenia'],
#  'GARD:0002297': ['fetal brain disruption sequence'],
#  'GARD:0002302': ['fetal enterovirus syndrome'],
#  'GARD:0002304': ['fetal iodine syndrome'],
#  'GARD:0002305': ['fetal left ventricular aneurysm'],
#  'GARD:0002309': ['fetal parainfluenza virus type 3 syndrome'],
#  'GARD:0002310': ['fetal parvovirus syndrome'],
#  'GARD:0002311': ['fetal phenothiazine syndrome'],
#  'GARD:0002321': ['fibrochondrogenesis'],
#  'GARD:0002327': ['fibrosarcoma'],
#  'GARD:0002333': ['fibular hypoplasia scapulo pelvic dysplasia absent'],
#  'GARD:0002349': ['focal alopecia congenital megalencephaly'],
#  'GARD:0002350': ['focal or multifocal malformations in neuronal migration'],
#  'GARD:0002354': ['basaloid follicular hamartoma'],
#  'GARD:0002357': ['follicular lymphoreticuloma'],
#  'GARD:0002358': ['fontaine farriaux blanckaert syndrome'],
#  'GARD:0002366': ['fragile x syndrome type 1'],
#  'GARD:0002367': ['fragile x syndrome type 2'],
#  'GARD:0002368': ['fragile x syndrome type 3'],
#  'GARD:0002371': ['franceschini vardeu guala syndrome'],
#  'GARD:0002375': ['frasier syndrome'],
#  'GARD:0002377': [],
#  'GARD:0002389': ['fronto nasal malformation cloacal exstrophy'],
#  'GARD:0002393': ['frontonasal dysplasia acromelic'],
#  'GARD:0002394': ['frontonasal dysplasia klippel feil syndrome'],
#  'GARD:0002395': ['frontonasal dysplasia phocomelic upper limbs'],
#  'GARD:0002407': ['fryns fabry remans syndrome'],
#  'GARD:0002409': ['fryns smeets thiry syndrome'],
#  'GARD:0002411': ['fukuda miyanomae nakata syndrome'],
#  'GARD:0002414': ['functioning pancreatic endocrine tumor'],
#  'GARD:0002415': ['fuqua berkovitz syndrome'],
#  'GARD:0002417': ['muscular atrophy ataxia retinitis pigmentosa and diabetes mellitus'],
#  'GARD:0002424': ['galactosemia'],
#  'GARD:0002444': ['gaucher ichthyosis restrictive dermopathy'],
#  'GARD:0002452': ['glaucoma, ectopia, microspherophakia, stiff joints and short stature syndrome'],
#  'GARD:0002455': ['genetic reflex epilepsy'],
#  'GARD:0002458': ['genital dwarfism'],
#  'GARD:0002459': ['genital dwarfism, turner type'],
#  'GARD:0002464': ['gershinibaruch leibo syndrome'],
#  'GARD:0002471': ['gigantism advanced bone age hoarse cry'],
#  'GARD:0002482': ['glaucoma iridogoniodysgenesia'],
#  'GARD:0002483': ['glaucoma sleep apnea'],
#  'GARD:0002484': ['glaucoma type 1c'],
#  'GARD:0002485': ['glaucoma, congenital'],
#  'GARD:0002486': ['glaucoma, hereditary'],
#  'GARD:0002487': ['glaucoma, hereditary adult type 1a'],
#  'GARD:0002488': ['glaucoma, hereditary juvenile type 1b'],
#  'GARD:0002489': ['glaucoma, primary infantile type 3a'],
#  'GARD:0002495': ['glossopalatine ankylosis micrognathia ear anomalies'],
#  'GARD:0002502': ['glucosephosphate isomerase deficiency'],
#  'GARD:0002503': ['glucosidase acid-1,4-alpha deficiency'],
#  'GARD:0002505': ['glutamate decarboxylase deficiency'],
#  'GARD:0002521': ['gm2 gangliosidosis, 0 variant'],
#  'GARD:0002522': ['gm2-gangliosidosis, b, b1, ab variant'],
#  'GARD:0002538': ['gonadal dysgenesis'],
#  'GARD:0002539': ['gonadal dysgenesis mixed'],
#  'GARD:0002540': ['gonadal dysgenesis turner type'],
#  'GARD:0002541': ['gonadal dysgenesis xy type associated anomalies'],
#  'GARD:0002546': ['gonococcal conjunctivitis'],
#  'GARD:0002580': ['dermoids of cornea'],
#  'GARD:0002586': ['hall-riggs syndrome'],
#  'GARD:0002627': ['hemangiopericytoma'],
#  'GARD:0002630': ['hemi 3 syndrome'],
#  'GARD:0002641': ['hemoglobin e disease'],
#  'GARD:0002642': ['hemolytic anemia lethal congenital nonspherocytic with genital and other abnormalities'],
#  'GARD:0002649': ['heparane sulfamidase deficiency'],
#  'GARD:0002650': ['heparin-induced thrombocytopenia'],
#  'GARD:0002651': ['hepatic cystic hamartoma'],
#  'GARD:0002657': ['hepatoblastoma'],
#  'GARD:0002661': ['hereditary nodular heterotopia'],
#  'GARD:0002663': ['hereditary resistance to anti-vitamin k'],
#  'GARD:0002671': ['herrmann opitz craniosynostosis'],
#  'GARD:0002682': ['ectodermal dysplasia, hidrotic, christianson-fourie type'],
#  'GARD:0002692': ['hip subluxation'],
#  'GARD:0002698': ['hirschsprung disease type 2'],
#  'GARD:0002703': ['hirschsprung nail hypoplasia dysmorphism'],
#  'GARD:0002706': ['his bundle tachycardia'],
#  'GARD:0002712': ['hmg coa synthetase deficiency'],
#  'GARD:0002720': ['holoacardius amorphus'],
#  'GARD:0002732': ['homocystinuria due to defect in methylation cbl e'],
#  'GARD:0002733': ['homocystinuria due to defect in methylation cbl g'],
#  'GARD:0002737': ['horn kolb syndrome'],
#  'GARD:0002749': ['humeroradioulnar synostosis'],
#  'GARD:0002755': ['hunter mcdonald syndrome'],
#  'GARD:0002764': ['hydatidosis'],
#  'GARD:0002767': ['hydrocephalus autosomal recessive'],
#  'GARD:0002776': ['hydrocephalus skeletal anomalies'],
#  'GARD:0002791': ['hyperbilirubinemia transient familial neonatal'],
#  'GARD:0002793': ['hyperbilirubinemia type 2'],
#  'GARD:0002800': ['hypercalcinuria macular coloboma'],
#  'GARD:0002811': ['hypergonadotropic ovarian failure, familial or sporadic'],
#  'GARD:0002818': ['hyperinsulinism due to glucokinase deficiency'],
#  'GARD:0002819': ['hyperinsulinism due to glutamodehydrogenase deficiency'],
#  'GARD:0002821': ['hyperinsulinism, diffuse'],
#  'GARD:0002838': ['neonatal severe hyperparathyroidism'],
#  'GARD:0002848': ['hypertelorism and tetralogy of fallot'],
#  'GARD:0002856': ['hyperthermia induced defects'],
#  'GARD:0002864': ['hypertrichosis lanuginosa, acquired'],
#  'GARD:0002871': ['hypertryptophanemia'],
#  'GARD:0002874': ['hypoaldosteronism'],
#  'GARD:0002877': ['hypocalcemia, autosomal dominant'],
#  'GARD:0002882': ['achondrogenesis'],
#  'GARD:0002883': ['hypodermyasis'],
#  'GARD:0002887': ['hypofibrinogenemia, familial'],
#  'GARD:0002889': ['hypoglycemia with deficiency of glycogen synthetase in the liver'],
#  'GARD:0002895': ['hypogonadism primary partial alopecia'],
#  'GARD:0002897': ['hypogonadism, isolated, hypogonadotropic'],
#  'GARD:0002907': ['hypomandibular faciocranial dysostosis'],
#  'GARD:0002910': ['familial isolated hypoparathyroidism'],
#  'GARD:0002914': ['hypoparathyroidism x-linked'],
#  'GARD:0002922': ['hypoplastic right heart syndrome'],
#  'GARD:0002929': ['hypospadias familial'],
#  'GARD:0002938': ['hypothyroidism due to iodide transport defect'],
#  'GARD:0002943': ['hypoxanthine guanine phosphoribosyltransferase deficiency'],
#  'GARD:0002957': ['ichthyosis-mental retardation syndrome with large keratohyalin granules in the skin'],
#  'GARD:0002967': ['ichthyosis linearis circumflexa'],
#  'GARD:0002984': ['immune deficiency, familial variable'],
#  'GARD:0002995': ['infant epilepsy with migrant focal crisis'],
#  'GARD:0002996': ['infantile axonal neuropathy'],
#  'GARD:0002998': ['infantile myofibromatosis'],
#  'GARD:0003004': ['infantile striato thalamic degeneration'],
#  'GARD:0003005': ['infundibulopelvic dysgenesis'],
#  'GARD:0003009': ['insulin-resistance type b'],
#  'GARD:0003010': ['insulinoma'],
#  'GARD:0003026': ['iridogoniodysgenesis type 2'],
#  'GARD:0003070': ['kallmann syndrome 2'],
#  'GARD:0003073': ['kallmann syndrome 3'],
#  'GARD:0003091': ['keratoconus posticus circumscriptus'],
#  'GARD:0003112': ['anaplastic large cell lymphoma'],
#  'GARD:0003159': ['lactate dehydrogenase deficiency'],
#  'GARD:0003163': ['lactic acidosis congenital infantile'],
#  'GARD:0003178': ['diffuse large b-cell lymphoma'],
#  'GARD:0003191': ['laryngocele'],
#  'GARD:0003194': ['larynx atresia'],
#  'GARD:0003198': ['laterality defects dominant'],
#  'GARD:0003214': ['leg absence deformity cataract'],
#  'GARD:0003219': ['leiomyomatosis of esophagus, cataract and hematuria'],
#  'GARD:0003225': ['lethal chondrodysplasia moerman type'],
#  'GARD:0003226': ['lethal chondrodysplasia seller type'],
#  'GARD:0003232': ['leukoencephalopathy palmoplantar keratoderma'],
#  'GARD:0003259': ['linear hamartoma syndrome'],
#  'GARD:0003262': ['lipidosis with triglycerid storage disease'],
#  'GARD:0003285': ['long qt syndrome 2'],
#  'GARD:0003286': ['long qt syndrome 3'],
#  'GARD:0003293': ['dwarfism, low-birth-weight type with unresponsiveness to growth hormone'],
#  'GARD:0003328': ['congenital lymphedema'],
#  'GARD:0003356': ['male pseudohermaphroditism due to defective lh molecule'],
#  'GARD:0003360': ['malignant germ cell tumor'],
#  'GARD:0003387': ['marfanoid hypermobility syndrome'],
#  'GARD:0003388': ['marfanoid habitus-autosomal recessive intellectual disability syndrome'],
#  'GARD:0003389': ['marginal glioneuronal heterotopia'],
#  'GARD:0003393': ['markel vikkula mulliken syndrome'],
#  'GARD:0003399': ['maroteaux stanescu cousin syndrome'],
#  'GARD:0003401': ['marphanoid syndrome type de silva'],
#  'GARD:0003440': ['median nodule of the upper lip'],
#  'GARD:0003441': ['medrano roldan syndrome'],
#  'GARD:0003444': ['megaepiphyseal dwarfism'],
#  'GARD:0003454': ['meigel disease'],
#  'GARD:0003471': ['meningocele'],
#  'GARD:0003472': ['meningococcemia'],
#  'GARD:0003480': ['cerebrooculonasal syndrome'],
#  'GARD:0003521': ['smith-fineman-myers syndrome'],
#  'GARD:0003549': ['mesomelia'],
#  'GARD:0003556': ['mesomelic dysplasia skin dimples'],
#  'GARD:0003557': ['thai symphalangism syndrome'],
#  'GARD:0003559': ['metacarpals 4 and 5 fusion'],
#  'GARD:0003565': ['metaphyseal chondrodysplasia, others'],
#  'GARD:0003568': ['metaphyseal dysplasia maxillary hypoplasia brachydactyly'],
#  'GARD:0003596': ['microbrachycephaly ptosis cleft lip'],
#  'GARD:0003603': ['microcephaly'],
#  'GARD:0003611': ['microcephaly chorioretinopathy recessive form'],
#  'GARD:0003615': ['microcephaly glomerulonephritis marfanoid habitus'],
#  'GARD:0003629': ['microcephaly microphthalmos blindness'],
#  'GARD:0003636': ['microcornea corectopia macular hypoplasia'],
#  'GARD:0003652': ['microscopic polyangiitis'],
#  'GARD:0003660': ['midline cleft of lower lip'],
#  'GARD:0003676': ['mirror polydactyly segmentation and limbs defects'],
#  'GARD:0003685': ['mitral atresia'],
#  'GARD:0003687': ['mitral valve prolapse, familial, autosomal dominant'],
#  'GARD:0003824': ['multiple carboxylase deficiency'],
#  'GARD:0003830': ['multiple endocrine neoplasia type 2'],
#  'GARD:0003831': ['multiple fibrofolliculoma familial'],
#  'GARD:0003845': ['muscular dystrophy limb girdle type 2a, erb type'],
#  'GARD:0003855': ['muscular dystrophy, congenital, merosin-positive'],
#  'GARD:0003857': ['muscular fibrosis multifocal obstructed vessels'],
#  'GARD:0003858': ['muscular phosphorylase kinase deficiency'],
#  'GARD:0003879': ['myoglobinuria recurrent'],
#  'GARD:0003959': ['neuroectodermal endocrine syndrome'],
#  'GARD:0003963': ['neuroepithelioma'],
#  'GARD:0003992': ['niemann-pick disease type c2'],
#  'GARD:0004028': ['oculo skeletal renal syndrome'],
#  'GARD:0004034': ['oculocerebral hypopigmentation syndrome type preus'],
#  'GARD:0004043': ['oculodentodigital dysplasia dominant'],
#  'GARD:0004051': ['odonto onycho dysplasia with alopecia'],
#  'GARD:0004054': ['odontoonychodermal dysplasia'],
#  'GARD:0004065': ['oligodactyly tetramelic postaxial'],
#  'GARD:0004070': ['olivopontocerebellar atrophy deafness'],
#  'GARD:0004081': ['omphalomesenteric cyst'],
#  'GARD:0004089': ['opthalmomandibulomelic dysplasia'],
#  'GARD:0004098': ['opsismodysplasia'],
#  'GARD:0004107': ['optic pathway glioma'],
#  'GARD:0004114': ['organic mood syndrome'],
#  'GARD:0004136': ['osteodysplasia familial anderson type'],
#  'GARD:0004168': ['otodental dysplasia'],
#  'GARD:0004169': ['otofaciocervical syndrome'],
#  'GARD:0004174': ['otosclerosis, familial'],
#  'GARD:0004176': ['ouvrier billson syndrome'],
#  'GARD:0004204': ['pancreatic adenoma'],
#  'GARD:0004210': ['pancreatoblastoma'],
#  'GARD:0004261': ['pauciarticular chronic arthritis'],
#  'GARD:0004268': ['tryptophanuria with dwarfism'],
#  'GARD:0004336': ['phosphomannoisomerase deficiency'],
#  'GARD:0004344': ['piebaldism'],
#  'GARD:0004354': ['pierre robin syndrome skeletal dysplasia polydactyly'],
#  'GARD:0004356': ['pigment-dispersion syndrome'],
#  'GARD:0004371': ['refsum disease with increased pipecolic acidemia'],
#  'GARD:0004386': ['pneumocystosis'],
#  'GARD:0004415': ['polydactyly postaxial dental and vertebral'],
#  'GARD:0004418': ['polydactyly syndrome middle ray duplication'],
#  'GARD:0004428': ['polysyndactyly cardiac malformation'],
#  'GARD:0004438': ['porokeratosis of mibelli'],
#  'GARD:0004453': ['positive rheumatoid factor polyarthritis'],
#  'GARD:0004457': ['posterior uveitis'],
#  'GARD:0004474': ['precocious puberty, gonadotropin-dependent'],
#  'GARD:0004477': ['prekallikrein deficiency, congenital'],
#  'GARD:0004487': ['primary tubular proximal acidosis'],
#  'GARD:0004505': ['progressive kinking of the hair, acquired'],
#  'GARD:0004513': ['properdin deficiency'],
#  'GARD:0004524': ['protein s deficiency'],
#  'GARD:0004525': ['proteus like syndrome mental retardation eye defect'],
#  'GARD:0004531': ['proximal spinal muscular atrophy'],
#  'GARD:0004538': ['pseudo-turner syndrome'],
#  'GARD:0004547': ['pseudohermaphrodism anorectal anomalies'],
#  'GARD:0004568': ['pterygium colli mental retardation digital anomalies'],
#  'GARD:0004569': ['pterygium of the conjunctiva and cornea'],
#  'GARD:0004577': ['ptosis strabismus ectopic pupils'],
#  'GARD:0004585': ['pulmonary artery agenesis'],
#  'GARD:0004586': ['pulmonary artery coming from the aorta'],
#  'GARD:0004587': ['pulmonary artery familial dilatation'],
#  'GARD:0004588': ['pulmonary atresia with ventricular septal defect'],
#  'GARD:0004589': ['congenital pulmonary artery branch stenosis'],
#  'GARD:0004592': ['pulmonary hypoplasia, familial primary'],
#  'GARD:0004593': ['pulmonary sequestration'],
#  'GARD:0004594': ['pulmonary supravalvular stenosis'],
#  'GARD:0004595': ['pulmonary surfactant protein b, deficiency of'],
#  'GARD:0004597': ['pulmonary valves agenesis'],
#  'GARD:0004600': ['pulmonary atresia with intact ventricular septum'],
#  'GARD:0004614': ['pyomyositis'],
#  'GARD:0004621': ['pyruvate kinase deficiency, liver type'],
#  'GARD:0004645': ['recurrent peripheral facial palsy'],
#  'GARD:0004655': ['renal caliceal diverticuli deafness'],
#  'GARD:0004664': ['renal genital middle ear anomalies'],
#  'GARD:0004667': ['distal renal tubular acidosis'],
#  'GARD:0004672': ['renier gabreels jasper syndrome'],
#  'GARD:0004680': ['retinal dysplasia x-linked'],
#  'GARD:0004685': ['retinohepatoendocrinologic syndrome'],
#  'GARD:0004687': ['retinopathy aplastic anemia neurological abnormalities'],
#  'GARD:0004704': ['rhizomelic pseudopolyarthritis'],
#  'GARD:0004737': ['rokitansky sequence'],
#  'GARD:0004748': ['ruvalcaba syndrome'],
#  'GARD:0004818': ['shigellosis'],
#  'GARD:0004880': ['sinus node disease and myopia'],
#  'GARD:0004909': ['spastic angina with healthy coronary artery'],
#  'GARD:0004912': ['spastic paraparesis'],
#  'GARD:0004915': ['spastic paraplegia-epilepsy-intellectual disability syndrome'],
#  'GARD:0004917': ['spastic paraplegia 5b'],
#  'GARD:0004923': ['spastic paraplegia 2'],
#  'GARD:0004931': ['spastic paraplegia-glaucoma-intellectual disability syndrome'],
#  'GARD:0004940': ['spina bifida hypospadias'],
#  'GARD:0004958': ['spinocerebellar ataxia with dysmorphism'],
#  'GARD:0004965': ['split hand split foot malformation autosomal recessive'],
#  'GARD:0004971': ['spondylarthropathy'],
#  'GARD:0004988': ['spondylohypoplasia, arthrogryposis and popliteal pterygium'],
#  'GARD:0004992': ['spondylometaphyseal dysplasia east-african type'],
#  'GARD:0004998': ['spotted fever'],
#  'GARD:0005025': ['stiff skin syndrome'],
#  'GARD:0005050': ['subependymal nodular heterotopia'],
#  'GARD:0005051': ['subpulmonary stenosis'],
#  'GARD:0005070': ['symmetrical thalamic calcifications'],
#  'GARD:0005074': ['symphalangism distal'],
#  'GARD:0005085': ['syndactyly ectodermal dysplasia cleft lip palate hand foot'],
#  'GARD:0005091': ['syngnathia cleft palate'],
#  'GARD:0005092': ['syngnathia multiple anomalies'],
#  'GARD:0005094': ['synostosis of talus and calcaneus short stature'],
#  'GARD:0005106': ['systemic necrotizing angitis'],
#  'GARD:0005108': ['t-cell lymphoma 1a'],
#  'GARD:0005140': ['embryonal carcinoma'],
#  'GARD:0005175': ['thomas syndrome'],
#  'GARD:0005180': ['thoracic dysplasia hydrocephalus syndrome'],
#  'GARD:0005181': ['thoraco abdominal enteric duplication'],
#  'GARD:0005185': ['thoracopelvic dysostosis'],
#  'GARD:0005195': ['thrombomodulin anomalies, familial'],
#  'GARD:0005216': ['tick-borne encephalitis'],
#  'GARD:0005234': ['tracheobronchomegaly'],
#  'GARD:0005261': ['trichodysplasia xeroderma'],
#  'GARD:0005263': ['trichofolliculoma'],
#  'GARD:0005267': ['trichoodontoonychial dysplasia'],
#  'GARD:0005277': ['trigonocephaly bifid nose acral anomalies'],
#  'GARD:0005286': ['triopia'],
#  'GARD:0005304': ['trisomy 12 mosaicism'],
#  'GARD:0005342': ['trisomy 3 mosaicism'],
#  'GARD:0005388': ['tyrosine-oxidase temporary deficiency'],
#  'GARD:0005425': ['urachal cyst'],
#  'GARD:0005432': ['urogenital adysplasia'],
#  'GARD:0005436': ['usher syndrome, type 1b'],
#  'GARD:0005438': ['usher syndrome, type 1d'],
#  'GARD:0005439': ['usher syndrome, type 1e'],
#  'GARD:0005440': ['usher syndrome type 2a'],
#  'GARD:0005441': ['usher syndrome, type 2b'],
#  'GARD:0005442': ['usher syndrome type 3a'],
#  'GARD:0005465': ['vasquez hurst sotos syndrome'],
#  'GARD:0005469': ['velofacioskeletal syndrome'],
#  'GARD:0005474': ['ventricular fibrillation, idiopathic'],
#  'GARD:0005485': ['verrucous nevus acanthokeratolytic'],
#  'GARD:0005494': ['viral hemorrhagic fever'],
#  'GARD:0005495': ['virilizing ovarian tumor'],
#  'GARD:0005506': ['vitreoretinal degeneration'],
#  'GARD:0005539': ['acromelic frontonasal dysostosis'],
#  'GARD:0005593': ['intrauterine growth retardation with increased mitomycin c sensitivity'],
#  'GARD:0005604': ['x-linked intellectual disability, turner type'],
#  'GARD:0005613': ['acsl4-related intellectual disability'],
#  'GARD:0005614': ['arx-related intellectual disability'],
#  'GARD:0005644': ['cardiomyopathy dilated with conduction defect type 2'],
#  'GARD:0005648': ['photosensitive epilepsy'],
#  'GARD:0005651': ['polymorphous low-grade adenocarcinoma'],
#  'GARD:0005654': ['alveolar soft part sarcoma'],
#  'GARD:0005657': ['periodic fever, aphthous stomatitis, pharyngitis and adenitis'],
#  'GARD:0005671': ['46,xx gonadal dysgenesis epibulbar dermoid'],
#  'GARD:0005694': ['retinitis pigmentosa'],
#  'GARD:0005722': ['acrodermatitis'],
#  'GARD:0005741': ['adenocarcinoid tumor'],
#  'GARD:0005742': ['lung adenocarcinoma'],
#  'GARD:0005751': ['adrenal cancer'],
#  'GARD:0005755': ['adrenal medulla cancer'],
#  'GARD:0005765': ['aids dysmorphic syndrome'],
#  'GARD:0005768': ['albinism'],
#  'GARD:0005776': ['allergic angiitis'],
#  'GARD:0005779': ['allergic encephalomyelitis'],
#  'GARD:0005791': ['amelogenesis imperfecta'],
#  'GARD:0005794': ['aminoaciduria'],
#  'GARD:0005813': ['angiosarcoma of the liver'],
#  'GARD:0005814': ['angiosarcoma of the scalp'],
#  'GARD:0005816': ['aniridia'],
#  'GARD:0005834': ['aphthous stomatitis'],
#  'GARD:0005856': ['aspergillosis'],
#  'GARD:0005863': ['athetosis'],
#  'GARD:0005918': ['beta-galactosidase-1 deficiency'],
#  'GARD:0005924': ['biliary tract cancer'],
#  'GARD:0005932': ['blepharophimosis'],
#  'GARD:0005948': ["bowen's disease"],
#  'GARD:0005951': ['bowenoid papulosis'],
#  'GARD:0005962': ['bronchopulmonary dysplasia'],
#  'GARD:0005996': ['carcinoma of the vocal tract'],
#  'GARD:0005999': ['cardiospasm'],
#  'GARD:0006004': ['cartilaginous cancer'],
#  'GARD:0006010': ['cavernous lymphangioma'],
#  'GARD:0006019': ['cerebellar degeneration'],
#  'GARD:0006025': ['cerebral ventricle cancer'],
#  'GARD:0006036': ['cherubism'],
#  'GARD:0006037': ['chiari-frommel syndrome'],
#  'GARD:0006040': ['childhood disintegrative disorder'],
#  'GARD:0006042': ['intrahepatic cholangiocarcinoma'],
#  'GARD:0006047': ['chondroblastoma'],
#  'GARD:0006049': ['rhizomelic chondrodysplasia punctata type 1'],
#  'GARD:0006050': ['chondrodysplasia punctata with steroid sulfatase deficiency'],
#  'GARD:0006051': ['chondrodystrophy'],
#  'GARD:0006052': ['chondroma'],
#  'GARD:0006055': ['chondrosarcoma'],
#  'GARD:0006059': ['choriocarcinoma'],
#  'GARD:0006060': ['chorioretinitis'],
#  'GARD:0006062': ['choroiditis'],
#  'GARD:0006064': ['chromophobe renal cell carcinoma'],
#  'GARD:0006065': ['chromosomal triplication'],
#  'GARD:0006125': ['cogan-reese syndrome'],
#  'GARD:0006137': ['colonic malakoplakia'],
#  'GARD:0006141': ['compartment syndrome'],
#  'GARD:0006149': ['congenital aplastic anemia'],
#  'GARD:0006150': ['congenital arteriovenous shunt'],
#  'GARD:0006154': ['congenital cardiovascular shunt'],
#  'GARD:0006168': ['congenital hepatic fibrosis'],
#  'GARD:0006169': ['hepatoerythropoietic porphyria'],
#  'GARD:0006177': ['congenital nonhemolytic jaundice'],
#  'GARD:0006193': ['cor biloculare'],
#  'GARD:0006200': ['coronary artery aneurysm'],
#  'GARD:0006205': ['cramp-fasciculation syndrome'],
#  'GARD:0006218': ['cryptococcosis'],
#  'GARD:0006219': ['cryptosporidiosis'],
#  'GARD:0006226': ['cutaneous t-cell lymphoma'],
#  'GARD:0006240': ['d-minus hemolytic uremic syndrome (d-hus)'],
#  'GARD:0006241': ['d-plus hemolytic uremic syndrome (d+hus)'],
#  'GARD:0006285': ['doxorubicin induced cardiomyopathy'],
#  'GARD:0006314': ['eccentrochondrodysplasia'],
#  'GARD:0006316': ['eclampsia'],
#  'GARD:0006317': ['ectodermal dysplasia'],
#  'GARD:0006318': ['ectopic pregnancy'],
#  'GARD:0006323': ['eisenmenger syndrome'],
#  'GARD:0006335': ['enchondroma'],
#  'GARD:0006339': ['endometrial stromal sarcoma'],
#  'GARD:0006340': ['endomyocardial fibrosis'],
#  'GARD:0006343': ['enteropathica'],
#  'GARD:0006346': ['eosinophilic cryptitis'],
#  'GARD:0006347': ['eosinophilic cystitis'],
#  'GARD:0006355': ['venezuelan equine encephalitis'],
#  'GARD:0006359': ['epidermolysis bullosa'],
#  'GARD:0006370': ['erysipelas'],
#  'GARD:0006378': ['erythroplakia'],
#  'GARD:0006381': ['esophageal atresia'],
#  'GARD:0006384': ['esophageal varices'],
#  'GARD:0006392': ['exercise-induced anaphylaxis'],
#  'GARD:0006393': ['exfoliative dermatitis'],
#  'GARD:0006410': ['familial deafness'],
#  'GARD:0006427': ["farmer's lung"],
#  'GARD:0006428': ['fascioliasis'],
#  'GARD:0006454': ['necrotizing fasciitis'],
#  'GARD:0006506': ['gigantism'],
#  'GARD:0006513': ['glioma'],
#  'GARD:0006514': ['gliomatosis cerebri'],
#  'GARD:0006518': ['glossodynia'],
#  'GARD:0006519': ['glossopharyngeal neuralgia'],
#  'GARD:0006545': ['granulocytopenia'],
#  'GARD:0006546': ['granuloma annulare'],
#  'GARD:0006548': ['granulomatous rosacea'],
#  'GARD:0006552': ['growth hormone deficiency'],
#  'GARD:0006557': ['hemangioendothelioma'],
#  'GARD:0006592': ['hemophilic arthropathy'],
#  'GARD:0006595': ['hemosiderosis'],
#  'GARD:0006614': ['hereditary ataxia'],
#  'GARD:0006616': ['myopathic carnitine deficiency'],
#  'GARD:0006618': ['neuronal ceroid lipofuscinosis 9'],
#  'GARD:0006621': ['hereditary elliptocytosis'],
#  'GARD:0006665': ['holoprosencephaly'],
#  'GARD:0006668': ['homologous wasting disease'],
#  'GARD:0006682': ['congenital hydrocephalus'],
#  'GARD:0006683': ['hydrolethalus syndrome'],
#  'GARD:0006692': ['hypercementosis'],
#  'GARD:0006717': ['hypertrophic branchial myopathy'],
#  'GARD:0006724': ['hypochondroplasia'],
#  'GARD:0006735': ['hypophosphatemic rickets'],
#  'GARD:0006739': ['hypoplastic left heart syndrome'],
#  'GARD:0006757': ['idiopathic dilatation of the pulmonary artery'],
#  'GARD:0006768': ['immune thrombocytopenia'],
#  'GARD:0006774': ['inborn renal aminoaciduria'],
#  'GARD:0006777': ['inclusion conjunctivitis'],
#  'GARD:0006797': ['japanese encephalitis'],
#  'GARD:0006841': ['kniest dysplasia'],
#  'GARD:0006843': ['wernicke-korsakoff syndrome'],
#  'GARD:0006845': ['autosomal recessive neuronal ceroid lipofuscinosis 4a'],
#  'GARD:0006866': ['biedl-bardet syndrome'],
#  'GARD:0006880': ['leiomyosarcoma'],
#  'GARD:0006895': ['leukodystrophy'],
#  'GARD:0006897': ['leukoplakia'],
#  'GARD:0006910': ['lipogranulomatosis'],
#  'GARD:0006913': ['liposarcoma'],
#  'GARD:0006920': ['loin pain hematuria syndrome'],
#  'GARD:0006932': ['lymph node neoplasm'],
#  'GARD:0006943': ['lymphomatoid granulomatosis'],
#  'GARD:0006944': ['lymphomatoid papulosis'],
#  'GARD:0006945': ['lymphomatous thyroiditis'],
#  'GARD:0006946': ['lymphosarcoma'],
#  'GARD:0006961': ['malaria'],
#  'GARD:0006985': ['marshall-smith syndrome'],
#  'GARD:0006991': ['maxillofacial dysostosis'],
#  'GARD:0007005': ['medulloblastoma'],
#  'GARD:0007015': ['meningioma'],
#  'GARD:0007029': ['metaphyseal chondrodysplasia schmid type'],
#  'GARD:0007030': ['metastatic insulinoma'],
#  'GARD:0007034': ['monoclonal gammopathy of undetermined significance'],
#  'GARD:0007036': ['microcephaly with chorioretinopathy, autosomal dominant form'],
#  'GARD:0007038': ['microencephaly'],
#  'GARD:0007041': ['midline lethal granuloma'],
#  'GARD:0007048': ['mitochondrial genetic disorders'],
#  'GARD:0007056': ['mononeuritis multiplex'],
#  'GARD:0007065': ['mucopolysaccharidosis'],
#  'GARD:0007103': ['multicentric reticulohistiocytosis'],
#  'GARD:0007116': [],
#  'GARD:0007122': ['myasthenia gravis'],
#  'GARD:0007125': ['mycoplasmal pneumonia'],
#  'GARD:0007130': ['myelitis'],
#  'GARD:0007137': ['myocarditis'],
#  'GARD:0007142': ['myoclonus epilepsy'],
#  'GARD:0007143': ['myoclonus epilepsy partial seizure'],
#  'GARD:0007179': ['nephrosclerosis'],
#  'GARD:0007185': ['neuroblastoma'],
#  'GARD:0007189': ['neuroendocrine carcinoma of the cervix'],
#  'GARD:0007190': ["alzheimer's disease without neurofibrillary tangles"],
#  'GARD:0007191': ['neurofibroma'],
#  'GARD:0007195': ['neuroleptic malignant syndrome'],
#  'GARD:0007196': ['neuroma biliary tract'],
#  'GARD:0007198': ['neuronal interstitial dysplasia'],
#  'GARD:0007216': ['non-lissencephalic cortical dysplasia'],
#  'GARD:0007222': ['nonsyndromic hereditary sensorineural hearing loss'],
#  'GARD:0007223': ['noonan syndrome 1'],
#  'GARD:0007231': ['ochronosis'],
#  'GARD:0007236': ['ocular melanoma'],
#  'GARD:0007238': ['ocular toxoplasmosis'],
#  'GARD:0007247': ['odontoma'],
#  'GARD:0007250': ['olivopontocerebellar atrophy'],
#  'GARD:0007260': ['oral leukoplakia'],
#  'GARD:0007263': ['oral squamous cell carcinoma'],
#  'GARD:0007264': ['oral submucous fibrosis'],
#  'GARD:0007272': ['ornithinemia'],
#  'GARD:0007281': ['osteochondroma'],
#  'GARD:0007285': ['osteomalacia'],
#  'GARD:0007286': ['osteomyelitis'],
#  'GARD:0007297': ['ovarian remnant syndrome'],
#  'GARD:0007313': ['mesomelic dwarfism of hypoplastic tibia and radius type'],
#  'GARD:0007320': ['optic neuritis'],
#  'GARD:0007326': ['paraneoplastic cerebellar degeneration'],
#  'GARD:0007348': ['cerebral sclerosis similar to pelizaeus-merzbacher disease'],
#  'GARD:0007352': ['pemphigus'],
#  'GARD:0007354': ['pemphigus foliaceus'],
#  'GARD:0007355': ['pemphigus vulgaris'],
#  'GARD:0007368': ['peripheral t-cell lymphoma'],
#  'GARD:0007375': ['persistent truncus arteriosus'],
#  'GARD:0007377': ['peters anomaly'],
#  'GARD:0007386': ['philadelphia-negative chronic myeloid leukemia'],
#  'GARD:0007400': ['pityriasis lichenoides chronica'],
#  'GARD:0007401': ['pityriasis rubra pilaris'],
#  'GARD:0007415': ['cutaneous polyarteritis nodosa'],
#  'GARD:0007425': ['polymyositis'],
#  'GARD:0007430': ['porencephaly'],
#  'GARD:0007437': ['post-traumatic epilepsy'],
#  'GARD:0007439': ['posterior urethral valves'],
#  'GARD:0007476': ['protoporphyria'],
#  'GARD:0007487': ['pseudomonas stutzeri infections'],
#  'GARD:0007504': ['pure red cell aplasia'],
#  'GARD:0007510': ['pyoderma gangrenosum'],
#  'GARD:0007516': ['rabies'],
#  'GARD:0007527': ['rasmussen encephalitis'],
#  'GARD:0007551': ['renal rickets'],
#  'GARD:0007552': ['renal tubular acidosis'],
#  'GARD:0007555': ['renoprival hypertension'],
#  'GARD:0007577': ['rheumatoid vasculitis'],
#  'GARD:0007585': ['rocky mountain spotted fever'],
#  'GARD:0007597': ['sacral plexopathy'],
#  'GARD:0007617': [],
#  'GARD:0007624': ['selenium poisoning'],
#  'GARD:0007628': ['severe combined immunodeficiency'],
#  'GARD:0007636': ['shwartzman phenomenon'],
#  'GARD:0007645': ['siderosis'],
#  'GARD:0007648': ['simian b virus infection'],
#  'GARD:0007650': ['sinus cancer'],
#  'GARD:0007674': ['spinal muscular atrophy'],
#  'GARD:0007680': ['spinal shock'],
#  'GARD:0007684': ['splenomegaly'],
#  'GARD:0007687': ['spondyloepiphyseal dysplasia'],
#  'GARD:0007711': ['sudden infant death syndrome'],
#  'GARD:0007720': ['synovial chondromatosis, familial with dwarfism'],
#  'GARD:0007722': ['synovitis'],
#  'GARD:0007724': ['syringobulbia'],
#  'GARD:0007725': ['syringomyelia'],
#  'GARD:0007756': ['thalassemia'],
#  'GARD:0007760': ['thrombasthenia'],
#  'GARD:0007771': ['tick paralysis'],
#  'GARD:0007781': ['torch syndrome'],
#  'GARD:0007791': ['tracheobronchomalacia'],
#  'GARD:0007794': ['transitional cell carcinoma'],
#  'GARD:0007796': ['transverse myelitis'],
#  'GARD:0007829': ['tuberculous uveitis'],
#  'GARD:0007837': ['urea cycle disorders'],
#  'GARD:0007846': ['van der woude syndrome 2'],
#  'GARD:0007854': ['vernal keratoconjunctivitis'],
#  'GARD:0007857': ['virus associated hemophagocytic syndrome'],
#  'GARD:0007914': ['yellow fever'],
#  'GARD:0007922': ['muscular dystrophy'],
#  'GARD:0008155': ['4-hydroxyphenylacetic aciduria'],
#  'GARD:0008170': ['severe infantile axonal neuropathy'],
#  'GARD:0008172': ['transient global amnesia'],
#  'GARD:0008192': ['uveal diseases'],
#  'GARD:0008196': ['spirurida infections'],
#  'GARD:0008200': ['secernentea infections'],
#  'GARD:0008203': ['rhabditida infections'],
#  'GARD:0008211': [],
#  'GARD:0008226': ['myeloid leukemia'],
#  'GARD:0008230': ['homocysteinemia'],
#  'GARD:0008232': ['hemangioblastoma'],
#  'GARD:0008235': ['esotropia'],
#  'GARD:0008238': ['choroid plexus carcinoma'],
#  'GARD:0008244': ['brain stem cancer'],
#  'GARD:0008254': ['omsk hemorrhagic fever'],
#  'GARD:0008258': ['mediastinal endodermal sinus tumors'],
#  'GARD:0008273': ['mutagen sensitivity'],
#  'GARD:0008313': ['angiomyomatous hamartoma'],
#  'GARD:0008325': ['trisomy 11 mosaicism'],
#  'GARD:0008349': ['amelogenesis imperfecta hypomaturation type'],
#  'GARD:0008382': ['2-methylacetoacetyl coa thiolase deficiency'],
#  'GARD:0008383': ['biliary hypoplasia'],
#  'GARD:0008386': ['global disaccharide intolerance'],
#  'GARD:0008394': ['hypolipoproteinemia'],
#  'GARD:0008417': ['renal cell carcinoma 4'],
#  'GARD:0008424': ['iminoglycinuria'],
#  'GARD:0008445': ['giant papillary conjunctivitis'],
#  'GARD:0008446': ['conjunctivitis with pseudomembrane'],
#  'GARD:0008465': ['hairy nose tip'],
#  'GARD:0008488': ['nonmedullary thyroid carcinoma, with or without cell oxyphilia'],
#  'GARD:0008491': ['radiation induced meningioma'],
#  'GARD:0008497': ['usher syndrome, type 2c'],
#  'GARD:0008539': ['urocanase deficiency'],
#  'GARD:0008550': ['dermatopathia pigmentosa reticularis'],
#  'GARD:0008559': ['familial wilms tumor 2'],
#  'GARD:0008571': ['polycystic bone disease'],
#  'GARD:0008582': ['autoimmune inner ear disease'],
#  'GARD:0008604': ['acanthoma'],
#  'GARD:0008629': ['acute hemorrhagic leukoencephalitis'],
#  'GARD:0008639': ['acute disseminated encephalomyelitis'],
#  'GARD:0008640': ['acute zonal occult outer retinopathy'],
#  'GARD:0008646': ['aneurysmal bone cysts'],
#  'GARD:0008648': ['desmoplastic infantile ganglioglioma'],
#  'GARD:0008650': ['embryonal sarcoma'],
#  'GARD:0008653': ['erythema elevatum diutinum'],
#  'GARD:0008689': ['autoimmune enteropathy'],
#  'GARD:0008704': ['benign angiitis of the central nervous system'],
#  'GARD:0008729': ['neurosyphilis'],
#  'GARD:0008742': ['limbic encephalitis'],
#  'GARD:0008743': ['meckel syndrome type 2'],
#  'GARD:0008744': ['meckel syndrome type 3'],
#  'GARD:0008746': ["sjogren's syndrome, juvenile, secondary to autoimmune disease"],
#  'GARD:0008750': ['coxa vara, congenital'],
#  'GARD:0009131': ['infective myositis'],
#  'GARD:0009134': ['congenital myotonic dystrophy'],
#  'GARD:0009139': ['autoimmune progesterone dermatitis'],
#  'GARD:0009149': ['retinitis pigmentosa 1'],
#  'GARD:0009159': ['dosage-sensitive sex reversal'],
#  'GARD:0009164': ['rippling muscle disease'],
#  'GARD:0009165': ['rippling muscle disease, 1'],
#  'GARD:0009170': ['hypotrichosis simplex'],
#  'GARD:0009171': ['iris hypoplasia and glaucoma'],
#  'GARD:0009211': ['aglossia and situs inversus'],
#  'GARD:0009225': ['tarsal carpal coalition syndrome'],
#  'GARD:0009227': ['duodenojejunal atresia with volvulus, absent dorsal mesentery and absent superior mesenteric artery'],
#  'GARD:0009228': ['renal agenesis'],
#  'GARD:0009236': ['disseminated infection with mycobacterium avium complex'],
#  'GARD:0009237': ['severe acute respiratory syndrome'],
#  'GARD:0009238': ['west nile virus infection'],
#  'GARD:0009244': ['cervical intraepithelial neoplasia'],
#  'GARD:0009253': ['absence of septum pellucidum'],
#  'GARD:0009255': ['early infantile epileptic encephalopathy'],
#  'GARD:0009270': ['endolymphatic sac tumor'],
#  'GARD:0009285': ['acanthamoeba keratitis'],
#  'GARD:0009289': ['baby rattle pelvic dysplasia'],
#  'GARD:0009296': ['spastic paraplegia 24'],
#  'GARD:0009301': ['cerebellar astrocytoma, childhood'],
#  'GARD:0009306': ['childhood brain stem glioma'],
#  'GARD:0009307': ['brain tumor, adult'],
#  'GARD:0009309': ['visual pathway and hypothalamic glioma, childhood'],
#  'GARD:0009310': ['brain tumor, childhood'],
#  'GARD:0009315': ['carcinoid tumor childhood'],
#  'GARD:0009316': ['carcinoid tumor'],
#  'GARD:0009319': ['chronic myeloproliferative disorders'],
#  'GARD:0009325': ['extragonadal germ cell tumor'],
#  'GARD:0009328': ['gallbladder cancer'],
#  'GARD:0009330': ['ovarian germ cell tumor'],
#  'GARD:0009334': ['hypopharyngeal cancer'],
#  'GARD:0009342': ['lip and oral cavity cancer'],
#  'GARD:0009348': ['vaginal cancer'],
#  'GARD:0009349': ['vulvar cancer'],
#  'GARD:0009360': ['oral cancer'],
#  'GARD:0009363': ['ovarian low malignant potential tumor'],
#  'GARD:0009369': ['pineoblastoma'],
#  'GARD:0009377': ['salivary gland cancer, adult'],
#  'GARD:0009384': ['metastatic squamous neck cancer with occult primary'],
#  'GARD:0009390': ['urethral cancer'],
#  'GARD:0009394': ['acute cholinergic dysautonomia'],
#  'GARD:0009398': ['sarcoma botryoides'],
#  'GARD:0009415': ['paraneoplastic neurologic disorders'],
#  'GARD:0009418': ['cochleosaccular degeneration of the inner ear and progressive cataracts'],
#  'GARD:0009422': ['melanocytic lesions of cns'],
#  'GARD:0009423': ['familial capillaro-venous leptomeningeal angiomatosis'],
#  'GARD:0009445': ['reactive angioendotheliomatosis'],
#  'GARD:0009451': ['xanthogranulomatous cholecystitis'],
#  'GARD:0009460': ['ovarian insufficiency, familial'],
#  'GARD:0009461': ['autoimmune oophoritis'],
#  'GARD:0009462': ['microspherophakia with hernia'],
#  'GARD:0009470': ['amyotrophic lateral sclerosis type 2'],
#  'GARD:0009472': ['anaplastic oligodendroglioma'],
#  'GARD:0009474': ['melorheostosis'],
#  'GARD:0009475': ['dysautonomia like disorder'],
#  'GARD:0009484': ['superficial siderosis of the central nervous system'],
#  'GARD:0009495': ['amelogenesis imperfecta pigmented hypomaturation type'],
#  'GARD:0009500': ['tremor hereditary essential, 2'],
#  'GARD:0009505': ['porokeratosis, disseminated superficial actinic 1'],
#  'GARD:0009519': ['autoimmune myocarditis'],
#  ...}

# %%
#Build the similar dataset
import random, itertools
i = 0
while i<500:
    gard_id = random.choice(list(multiple_names.keys()))
    rand_list = multiple_names[gard_id]
    pair_order_list = list(itertools.combinations(rand_list,2))
    #to avoid heavily weighting the non 
    if pair_order_list>3:
        pair_order_list = random.sample(pair_order_list,k=3)
        
    for term1, term2 in pair_order_list:
        thousand_dataset_dict["split"].append('train')
        thousand_dataset_dict["sid"].append(i)
        thousand_dataset_dict["term1"].append(term1)
        thousand_dataset_dict["term2"].append(term2)
        thousand_dataset_dict["gard_id1"].append(gard_id)
        thousand_dataset_dict["gard_id2"].append(gard_id)
        thousand_dataset_dict["score1"].append(5)
        thousand_dataset_dict["score2"].append(5)
        i+=1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/qv/8pl38v151l59mbwff3cpcwq00000gn/T/ipykernel_68338/1277624619.py in <module>
#       6     rand_list = multiple_names[gard_id]
#       7     pair_order_list = list(itertools.combinations(rand_list,2))
# ----> 8     for term1, term2 in random.sample(pair_order_list,k=2):
#       9         thousand_dataset_dict["split"].append('train')
#      10         thousand_dataset_dict["sid"].append(i)
#
# ~/opt/anaconda3/lib/python3.9/random.py in sample(self, population, k, counts)
#     447         randbelow = self._randbelow
#     448         if not 0 <= k <= n:
# --> 449             raise ValueError("Sample larger than population or is negative")
#     450         result = [None] * k
#     451         setsize = 21        # size of a small set minus size of an empty list
#
# ValueError: Sample larger than population or is negative

# %% [markdown]
# The number of pairings between names with same GARD ID is `n(n-1)/2`
# (positive pairings)

# %%
total_positive_pairings = int(sum([(len(l)*(len(l)-1))/2 for l in GARD_id_dict.values()]))

print(f"{total_positive_pairings:,}")
# Out:
# 36,509

# %%
all_names = []
for names in GARD_id_dict.values():
    for name in names:
        all_names.append(name)

print(len(all_names),len(set(all_names)))

num_names = len(all_names)
# Out:
# 19423 19423

# %% [markdown]
# The number of pairing between names without same GARD ID is `num(entries not in cluster) * num(entries in cluster)`
# (negative pairings)

# %%
total_negative_pairings = 0
for names in GARD_id_dict.values():
    total_negative_pairings+=(num_names - len(names))*len(names)
    
print(f"{total_negative_pairings:,}")
# Out:
# 377,160,488

# %%
max_comparisons = int(sum([(len(l)*(len(l)-1))/2 for l in GARD_id_dict.values()]))
max_comparisons

# %%
import pandas

# %% [markdown]
# Similar comparisons

# %%
https://sbert.net/datasets/stsbenchmark.tsv.gz
